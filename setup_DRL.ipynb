# %% [markdown]
# # Installing library

# %%
import gymnasium as gym
from stable_baselines3 import A2C

env = gym.make("CartPole-v1", render_mode="rgb_array")

model = A2C("MlpPolicy", env, verbose=1)
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render("human")
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 33.9         |
# |    ep_rew_mean        | 33.9         |
# | time/                 |              |
# |    fps                | 3152         |
# |    iterations         | 100          |
# |    time_elapsed       | 0            |
# |    total_timesteps    | 500          |
# | train/                |              |
# |    entropy_loss       | -0.627       |
# |    explained_variance | -0.060846686 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 99           |
# |    policy_loss        | 1.48         |
# |    value_loss         | 12           |
# ----------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 33         |
# |    ep_rew_mean        | 33         |
# | time/                 |            |
# |    fps                | 3438       |
# |    iterations         | 200        |
# |    time_elapsed       | 0          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -0.46      |
# |    explained_variance | -0.7883389 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 1.37       |
# |    value_loss         | 8.39       |
# --------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 28.6         |
# |    ep_rew_mean        | 28.6         |
# | time/                 |              |
# |    fps                | 3571         |
# |    iterations         | 300          |
# |    time_elapsed       | 0            |
# |    total_timesteps    | 1500         |
# | train/                |              |
# |    entropy_loss       | -0.519       |
# |    explained_variance | -0.055393815 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 299          |
# |    policy_loss        | 1.84         |
# |    value_loss         | 8.85         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 26.4         |
# |    ep_rew_mean        | 26.4         |
# | time/                 |              |
# |    fps                | 3594         |
# |    iterations         | 400          |
# |    time_elapsed       | 0            |
# |    total_timesteps    | 2000         |
# | train/                |              |
# |    entropy_loss       | -0.548       |
# |    explained_variance | -0.014548898 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 399          |
# |    policy_loss        | 0.936        |
# |    value_loss         | 6.54         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 24.7         |
# |    ep_rew_mean        | 24.7         |
# | time/                 |              |
# |    fps                | 3647         |
# |    iterations         | 500          |
# |    time_elapsed       | 0            |
# |    total_timesteps    | 2500         |
# | train/                |              |
# |    entropy_loss       | -0.609       |
# |    explained_variance | -0.008431435 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 499          |
# |    policy_loss        | 0.954        |
# |    value_loss         | 5.94         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 21.3         |
# |    ep_rew_mean        | 21.3         |
# | time/                 |              |
# |    fps                | 3662         |
# |    iterations         | 600          |
# |    time_elapsed       | 0            |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -0.498       |
# |    explained_variance | -0.024906993 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 0.695        |
# |    value_loss         | 5.8          |
# ----------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 21.4        |
# |    ep_rew_mean        | 21.4        |
# | time/                 |             |
# |    fps                | 3538        |
# |    iterations         | 700         |
# |    time_elapsed       | 0           |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -0.462      |
# |    explained_variance | -0.03977382 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 0.744       |
# |    value_loss         | 5.34        |
# ---------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 22.9       |
# |    ep_rew_mean        | 22.9       |
# | time/                 |            |
# |    fps                | 3580       |
# |    iterations         | 800        |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -0.456     |
# |    explained_variance | -0.0016433 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -12        |
# |    value_loss         | 910        |
# --------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 24.9          |
# |    ep_rew_mean        | 24.9          |
# | time/                 |               |
# |    fps                | 3619          |
# |    iterations         | 900           |
# |    time_elapsed       | 1             |
# |    total_timesteps    | 4500          |
# | train/                |               |
# |    entropy_loss       | -0.115        |
# |    explained_variance | 0.00013041496 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 899           |
# |    policy_loss        | 2.93          |
# |    value_loss         | 4.32          |
# -----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 27.3         |
# |    ep_rew_mean        | 27.3         |
# | time/                 |              |
# |    fps                | 3639         |
# |    iterations         | 1000         |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -0.428       |
# |    explained_variance | -0.024821043 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 0.369        |
# |    value_loss         | 3.92         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 30.1         |
# |    ep_rew_mean        | 30.1         |
# | time/                 |              |
# |    fps                | 3637         |
# |    iterations         | 1100         |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 5500         |
# | train/                |              |
# |    entropy_loss       | -0.428       |
# |    explained_variance | 0.0051380396 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1099         |
# |    policy_loss        | 1.17         |
# |    value_loss         | 3.44         |
# ----------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 33.1         |
# |    ep_rew_mean        | 33.1         |
# | time/                 |              |
# |    fps                | 3616         |
# |    iterations         | 1200         |
# |    time_elapsed       | 1            |
# |    total_timesteps    | 6000         |
# | train/                |              |
# |    entropy_loss       | -0.448       |
# |    explained_variance | -0.002071023 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1199         |
# |    policy_loss        | 0.613        |
# |    value_loss         | 2.99         |
# ----------------------------------------
# --------------------------------------
# | rollout/              |            |
# |    ep_len_mean        | 37.6       |
# |    ep_rew_mean        | 37.6       |
# | time/                 |            |
# |    fps                | 3610       |
# |    iterations         | 1300       |
# |    time_elapsed       | 1          |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -0.359     |
# |    explained_variance | 0.00157094 |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 1.12       |
# |    value_loss         | 2.53       |
# --------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 41.5           |
# |    ep_rew_mean        | 41.5           |
# | time/                 |                |
# |    fps                | 3610           |
# |    iterations         | 1400           |
# |    time_elapsed       | 1              |
# |    total_timesteps    | 7000           |
# | train/                |                |
# |    entropy_loss       | -0.534         |
# |    explained_variance | -0.00041556358 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1399           |
# |    policy_loss        | 0.422          |
# |    value_loss         | 2.11           |
# ------------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 45.6         |
# |    ep_rew_mean        | 45.6         |
# | time/                 |              |
# |    fps                | 3614         |
# |    iterations         | 1500         |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 7500         |
# | train/                |              |
# |    entropy_loss       | -0.549       |
# |    explained_variance | 0.0010427237 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1499         |
# |    policy_loss        | 0.529        |
# |    value_loss         | 1.74         |
# ----------------------------------------
# ------------------------------------------
# | rollout/              |                |
# |    ep_len_mean        | 49.2           |
# |    ep_rew_mean        | 49.2           |
# | time/                 |                |
# |    fps                | 3620           |
# |    iterations         | 1600           |
# |    time_elapsed       | 2              |
# |    total_timesteps    | 8000           |
# | train/                |                |
# |    entropy_loss       | -0.449         |
# |    explained_variance | -0.00054204464 |
# |    learning_rate      | 0.0007         |
# |    n_updates          | 1599           |
# |    policy_loss        | 0.229          |
# |    value_loss         | 1.39           |
# ------------------------------------------
# ----------------------------------------
# | rollout/              |              |
# |    ep_len_mean        | 53.9         |
# |    ep_rew_mean        | 53.9         |
# | time/                 |              |
# |    fps                | 3632         |
# |    iterations         | 1700         |
# |    time_elapsed       | 2            |
# |    total_timesteps    | 8500         |
# | train/                |              |
# |    entropy_loss       | -0.42        |
# |    explained_variance | -0.000697732 |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1699         |
# |    policy_loss        | 0.306        |
# |    value_loss         | 1.09         |
# ----------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 57.4        |
# |    ep_rew_mean        | 57.4        |
# | time/                 |             |
# |    fps                | 3645        |
# |    iterations         | 1800        |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -0.444      |
# |    explained_variance | 0.004169643 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | 0.297       |
# |    value_loss         | 0.805       |
# ---------------------------------------
# ---------------------------------------
# | rollout/              |             |
# |    ep_len_mean        | 63.4        |
# |    ep_rew_mean        | 63.4        |
# | time/                 |             |
# |    fps                | 3659        |
# |    iterations         | 1900        |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -0.427      |
# |    explained_variance | 9.23872e-06 |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | 0.257       |
# |    value_loss         | 0.574       |
# ---------------------------------------
# -----------------------------------------
# | rollout/              |               |
# |    ep_len_mean        | 68.1          |
# |    ep_rew_mean        | 68.1          |
# | time/                 |               |
# |    fps                | 3667          |
# |    iterations         | 2000          |
# |    time_elapsed       | 2             |
# |    total_timesteps    | 10000         |
# | train/                |               |
# |    entropy_loss       | -0.511        |
# |    explained_variance | 1.2814999e-05 |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 1999          |
# |    policy_loss        | 0.233         |
# |    value_loss         | 0.378         |
# -----------------------------------------
# 2024-11-08 01:15:58.637 Python[27654:745708] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-11-08 01:15:58.637 Python[27654:745708] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
