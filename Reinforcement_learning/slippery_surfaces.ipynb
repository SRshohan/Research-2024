# %% [markdown]
# # Grid World with Slippery Surfaces

# %% [markdown]
# S 0 0 0 G
# 0 X 0 X 0
# 0 0 S 0 0
# 0 X 0 X 0
# 0 0 0 0 0

# %% [markdown]
# α: Learning rate
# γ: Discount factor
# r: Reward for the current action
# s ′: Next state after taking action a from state 𝑠

# %%
# Setting up Q-Learning 

import numpy as np
import random

# Grid parameters 
grid_size = 5
slippery_cells = [(1,1), (3,2), (2,3), (3, 3)] # Examples slipeery 

#Q-learnig table Setup
q_table = np.zeros((grid_size, grid_size, 4)) # 4 Actions: up, down, left, right


def choose_action(state, epsilon=0.1):
    if random.uniform(0, 1) < epsilon: # Exploration
        rchoice = random.choices([0,1,2,3])
        print("Exploring: Taking a random action")
        return rchoice
    else:
        action = np.argmax(q_table[state])  # Best-known action (exploiting)
        print("Exploiting: Taking the best-known action")
        return action
    
# Policy Gradient setup (The brain)
policy = np.full((grid_size, grid_size, 4), 0.25) # Initialize with equal prob for each action

# %%
# Policy Gradient setup (The brain)
policy = np.full((grid_size, grid_size, 4), 0.25) # Initialize with equal prob for each action
print(policy)
# Out:
# [[[0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]]
#
#  [[0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]]
#
#  [[0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]]
#
#  [[0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]]
#
#  [[0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]
#   [0.25 0.25 0.25 0.25]]]

# %% [markdown]
# # This is a simple basic policy update

# %%
def policy_gradient_step(state, action, reward): #
    if reward > 0:
        policy[state][action] += 0.01 * reward 
    else:
        policy[state][action] -= 0.01 * reward 

    # Normalize probablities to keep the valid
    policy[state] = policy[state] / np.sum(policy[state])
    print(policy[state])

# Define slippery effect
def apply_slippery(action):
    if random.uniform(0, 1) < 0.1:  # 10% slip chance
        return random.choice([0, 1, 2, 3])  # Random action
    return action

# %% [markdown]
# # Testing the my setuo

# %%
# Environment setup
goal = (1,4)
reward_goal = 1
reward_step = -0.01 # Small penalty to encourage shorter path
reward_slip = -0.1

# Run multiple episodes to test learing
num_episodes = 50
for ep in range(num_episodes):
    state = (0,0) # Starting position
    total_reward = 0
    epsilon = max(0.1, 1 - ep / num_episodes) # Decrease epsilon to shift exploring to exploiting

    for step in range(50): # Max step per episodes
        # Choose an action (explore/exploit on Q-learning)
        action = choose_action(state, epsilon)

        # Apply slippery effect if the cell is slippery 
        if state in slippery_cells:
            action = apply_slippery(action=action)

        # Move the agent based on the action (0: up, 1: down, 2: left, 3: right)
        next_state = (state[0] + (action == 1) - (action == 0), state[1] + (action == 3) - (action == 2))


        # Check if next_state is within bounds
        if not (0 <= next_state[0] < grid_size and 0 <= next_state[1] < grid_size):
            next_state = state  # Stay in place if out of bounds
            reward = reward_step  # Penalty for attempting invalid move
        elif next_state == goal:
            reward = reward_goal  # Reward for reaching the goal
        elif next_state in slippery_cells:
            reward = reward_slip  # Penalty for landing on a slippery cell
        else:
            reward = reward_step  # Default step penalty


        # Update Q-table (Q-learning update)
        old_q_value = q_table[state][action]
        next_best_q = np.max(q_table[next_state])
        q_table[state][action] = old_q_value + 0.1 * (reward + 0.9 * next_best_q - old_q_value)

        # Update Policy using Policy Gradient (if goal reached)
        policy_gradient_step(state, action, reward)
        # Move to the next state
        state = next_state
        total_reward += reward

        # End the episode if the goal is reached
        if state == goal:
            print(f"Episode {ep + 1}: Reached goal in {step + 1} steps with total reward {total_reward:.2f}")
            break
    else:
        print(f"Episode {ep + 1}: Did not reach the goal. Total reward: {total_reward:.2f}")

# Print final Q-table and policy probabilities for inspection
print("Final Q-table:")
print(q_table)
print("Final Policy Probabilities:")
print(policy)
# Out:
# Exploring: Taking a random action
# [0.249975   0.249975   0.25007499 0.249975  ]
# Exploring: Taking a random action
# [0.24995001 0.24995001 0.25014998 0.24995001]
# Exploring: Taking a random action
# [0.24992501 0.250025   0.25012497 0.24992501]
# Exploring: Taking a random action
# [0.25000001 0.25       0.25009996 0.24990002]
# Exploring: Taking a random action
# [0.24997502 0.24997501 0.25017494 0.24987504]
# Exploring: Taking a random action
# [0.25005001 0.24995001 0.25014992 0.24985005]
# Exploring: Taking a random action
# [0.25002501 0.24992502 0.25012491 0.24992506]
# Exploring: Taking a random action
# [0.2501     0.24990003 0.2500999  0.24990007]
# Exploring: Taking a random action
# [0.25007499 0.24987504 0.25007489 0.24997507]
# Exploring: Taking a random action
# [0.25004999 0.24985006 0.25014988 0.24995008]
# Exploring: Taking a random action
# [0.25012497 0.24982507 0.25012487 0.24992508]
# Exploring: Taking a random action
# [0.25009997 0.24980009 0.25009986 0.25000008]
# Exploring: Taking a random action
# [0.25017495 0.24977512 0.25007485 0.24997509]
# Exploring: Taking a random action
# [0.25014993 0.24985013 0.25004984 0.24995009]
# Exploring: Taking a random action
# [0.25022491 0.24982515 0.25002484 0.2499251 ]
# Exploring: Taking a random action
# [0.25019989 0.24990016 0.24999984 0.24990011]
# Exploring: Taking a random action
# [0.25027486 0.24987517 0.24997484 0.24987512]
# Exploring: Taking a random action
# [0.25034983 0.24985019 0.24994985 0.24985014]
# Exploring: Taking a random action
# [0.2503248  0.2498252  0.24992486 0.24992514]
# Exploring: Taking a random action
# [0.25029977 0.24980022 0.24989987 0.25000014]
# Exploring: Taking a random action
# [0.25027474 0.24977525 0.24987488 0.25007514]
# Exploring: Taking a random action
# [0.25024971 0.24985026 0.24984989 0.25005013]
# Exploring: Taking a random action
# [0.25022469 0.24992527 0.24982491 0.25002513]
# Exploring: Taking a random action
# [0.25029966 0.24990028 0.24979993 0.25000013]
# Exploring: Taking a random action
# [0.25027463 0.24987529 0.24987494 0.24997513]
# Exploring: Taking a random action
# [0.25024961 0.24985031 0.24994995 0.24995014]
# Exploring: Taking a random action
# [0.25022459 0.24982532 0.25002495 0.24992514]
# Exploring: Taking a random action
# [0.25029956 0.24980034 0.24999995 0.24990015]
# Exploring: Taking a random action
# [0.25027453 0.24977537 0.24997495 0.24997516]
# Exploring: Taking a random action
# [0.2502495  0.24975039 0.24994995 0.25005015]
# Exploring: Taking a random action
# [0.25022448 0.24972542 0.24992496 0.25012514]
# Exploring: Taking a random action
# [0.25019946 0.24970045 0.24999996 0.25010013]
# Exploring: Taking a random action
# [0.25017444 0.24967548 0.25007495 0.25007512]
# Exploring: Taking a random action
# [0.25014943 0.24965052 0.25014994 0.25005012]
# Exploring: Taking a random action
# [0.25012442 0.24962555 0.25022492 0.25002511]
# Exploring: Taking a random action
# [0.25009941 0.24970058 0.2501999  0.25000011]
# Exploring: Taking a random action
# [0.25017439 0.24967562 0.25017488 0.24997512]
# Exploring: Taking a random action
# [0.25024936 0.24965065 0.25014986 0.24995012]
# Exploring: Taking a random action
# [0.25032433 0.24962569 0.25012485 0.24992513]
# Exploring: Taking a random action
# [0.2502993  0.24960073 0.25009984 0.25000013]
# Exploring: Taking a random action
# [0.25037426 0.24957577 0.25007483 0.24997513]
# Exploring: Taking a random action
# [0.25034923 0.24955082 0.25014982 0.24995014]
# Exploring: Taking a random action
# [0.2503242  0.24962585 0.25012481 0.24992514]
# Exploring: Taking a random action
# [0.25029917 0.24960089 0.25019979 0.24990015]
# Exploring: Taking a random action
# [0.25027414 0.24957594 0.25017477 0.24997516]
# Exploring: Taking a random action
# [0.25024911 0.24955098 0.25014975 0.25005015]
# Exploring: Taking a random action
# [0.25022409 0.24952603 0.25022473 0.25002515]
# Exploring: Taking a random action
# [0.25029906 0.24950108 0.25019971 0.25000015]
# Exploring: Taking a random action
# [0.25027403 0.24947613 0.25027468 0.24997515]
# Exploring: Taking a random action
# [0.250349   0.24945119 0.25024966 0.24995016]
# Episode 1: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25032397 0.24942624 0.25032463 0.24992516]
# Exploring: Taking a random action
# [0.25029894 0.2494013  0.25039959 0.24990017]
# Exploring: Taking a random action
# [0.25027391 0.24937637 0.25047454 0.24987519]
# Exploring: Taking a random action
# [0.25024888 0.24935143 0.25054948 0.2498502 ]
# Exploring: Taking a random action
# [0.25022386 0.2493265  0.25062442 0.24982522]
# Exploring: Taking a random action
# [0.25029883 0.24930157 0.25059936 0.24980024]
# Exploring: Taking a random action
# [0.25027381 0.24927664 0.25067429 0.24977526]
# Exploring: Taking a random action
# [0.25024878 0.24925171 0.25074922 0.24975029]
# Exploring: Taking a random action
# [0.25032375 0.24922679 0.25072415 0.24972531]
# Exploring: Taking a random action
# [0.25029872 0.24930186 0.25069908 0.24970034]
# Exploring: Taking a random action
# [0.25027369 0.24927693 0.25067401 0.24977537]
# Exploring: Taking a random action
# [0.25034866 0.24925201 0.25064894 0.24975039]
# Exploring: Taking a random action
# [0.25032362 0.24932708 0.25062388 0.24972542]
# Exploring: Taking a random action
# [0.25029859 0.24930215 0.25069881 0.24970045]
# Exploring: Taking a random action
# [0.25027357 0.24927722 0.25067374 0.24977547]
# Exploring: Taking a random action
# [0.25034853 0.24925229 0.25064868 0.2497505 ]
# Exploring: Taking a random action
# [0.2503235  0.24922737 0.25062362 0.24982551]
# Exploring: Taking a random action
# [0.25029847 0.24920245 0.25059856 0.24990052]
# Exploring: Taking a random action
# [0.25037343 0.24917753 0.2505735  0.24987554]
# Exploring: Taking a random action
# [0.25044839 0.24915262 0.25054845 0.24985055]
# Exploring: Taking a random action
# [0.25052333 0.2491277  0.25052339 0.24982557]
# Exploring: Taking a random action
# [0.25049828 0.24910279 0.25049834 0.24990058]
# Exploring: Taking a random action
# [0.25047324 0.24907789 0.2504733  0.24997558]
# Exploring: Taking a random action
# [0.25054818 0.24905298 0.25044825 0.24995059]
# Exploring: Taking a random action
# [0.25052313 0.24902808 0.25042321 0.25002558]
# Exploring: Taking a random action
# [0.25049808 0.24910317 0.25039817 0.25000058]
# Exploring: Taking a random action
# [0.25047303 0.24917825 0.25037313 0.24997559]
# Exploring: Taking a random action
# [0.25054798 0.24915333 0.2503481  0.24995059]
# Exploring: Taking a random action
# [0.25062292 0.24912842 0.25032306 0.2499256 ]
# Exploring: Taking a random action
# [0.25059786 0.2492035  0.25029803 0.24990061]
# Exploring: Taking a random action
# [0.2505728  0.24927857 0.25027301 0.24987562]
# Exploring: Taking a random action
# [0.25054774 0.24925365 0.25024798 0.24995063]
# Exploring: Taking a random action
# [0.25052269 0.24932871 0.25022296 0.24992563]
# Exploring: Taking a random action
# [0.25049764 0.24940377 0.25019794 0.24990064]
# Exploring: Taking a random action
# [0.2504726  0.24937884 0.25017292 0.24997565]
# Exploring: Taking a random action
# [0.25044755 0.24945389 0.25014791 0.24995065]
# Exploring: Taking a random action
# [0.25042251 0.24952894 0.2501229  0.24992566]
# Exploring: Taking a random action
# [0.25049746 0.24950399 0.25009789 0.24990067]
# Exploring: Taking a random action
# [0.25047241 0.24947904 0.25017287 0.24987568]
# Exploring: Taking a random action
# [0.25054736 0.24945409 0.25014785 0.24985069]
# Exploring: Taking a random action
# [0.25062229 0.24942915 0.25012284 0.24982571]
# Exploring: Taking a random action
# [0.25069722 0.24940421 0.25009783 0.24980073]
# Exploring: Taking a random action
# [0.25077215 0.24937927 0.25007282 0.24977575]
# Exploring: Taking a random action
# [0.25074707 0.24945433 0.25004782 0.24975078]
# Exploring: Taking a random action
# [0.250722   0.24942939 0.25002282 0.2498258 ]
# Exploring: Taking a random action
# [0.25069693 0.24940444 0.24999782 0.24990081]
# Exploring: Taking a random action
# [0.25067186 0.2494795  0.24997282 0.24987582]
# Exploiting: Taking the best-known action
# [0.2506468  0.24945455 0.25004782 0.24985083]
# Exploring: Taking a random action
# [0.25072173 0.24942961 0.25002281 0.24982585]
# Exploring: Taking a random action
# [0.25079665 0.24940467 0.24999781 0.24980087]
# Episode 2: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25077157 0.24947972 0.24997282 0.24977589]
# Exploring: Taking a random action
# [0.25084649 0.24945477 0.24994782 0.24975092]
# Exploring: Taking a random action
# [0.2508214  0.24942983 0.25002282 0.24972595]
# Exploring: Taking a random action
# [0.25079632 0.24950488 0.24999782 0.24970098]
# Exploring: Taking a random action
# [0.25077125 0.24947993 0.25007281 0.24967601]
# Exploring: Taking a random action
# [0.25074617 0.24945499 0.2501478  0.24965104]
# Exploring: Taking a random action
# [0.2507211  0.24953003 0.25012279 0.24962608]
# Exploring: Taking a random action
# [0.25069603 0.24960507 0.25009778 0.24960112]
# Exploring: Taking a random action
# [0.25077095 0.24958012 0.25007277 0.24957616]
# Exploring: Taking a random action
# [0.25074588 0.24955516 0.25004776 0.2496512 ]
# Exploring: Taking a random action
# [0.2508208  0.24953021 0.25002276 0.24962624]
# Exploring: Taking a random action
# [0.25079572 0.24960525 0.24999776 0.24960128]
# Exploring: Taking a random action
# [0.25087063 0.24958029 0.24997276 0.24957632]
# Exploring: Taking a random action
# [0.25084554 0.24955533 0.25004776 0.24955136]
# Exploring: Taking a random action
# [0.25092045 0.24953038 0.25002276 0.24952641]
# Exploring: Taking a random action
# [0.25089536 0.24950543 0.24999776 0.24960145]
# Exploring: Taking a random action
# [0.25097027 0.24948048 0.24997276 0.24957649]
# Exploring: Taking a random action
# [0.25094517 0.24945554 0.25004776 0.24955154]
# Exploring: Taking a random action
# [0.25092008 0.24943059 0.25012274 0.24952658]
# Exploring: Taking a random action
# [0.25099498 0.24940565 0.25009773 0.24950163]
# Exploring: Taking a random action
# [0.25096988 0.2494807  0.25007273 0.24947669]
# Exploring: Taking a random action
# [0.25104478 0.24945576 0.25004772 0.24945174]
# Exploring: Taking a random action
# [0.25101968 0.24953081 0.25002272 0.2494268 ]
# Exploring: Taking a random action
# [0.25099458 0.24950586 0.24999772 0.24950185]
# Exploring: Taking a random action
# [0.25096948 0.24948091 0.24997272 0.24957689]
# Exploring: Taking a random action
# [0.25094439 0.24945596 0.24994773 0.24965193]
# Exploring: Taking a random action
# [0.25091929 0.24943102 0.24992273 0.24972695]
# Exploring: Taking a random action
# [0.2508942  0.24950607 0.24989774 0.24970198]
# Exploring: Taking a random action
# [0.25086912 0.24948112 0.24997275 0.24967702]
# Exploring: Taking a random action
# [0.25094402 0.24945617 0.24994775 0.24965205]
# Exploring: Taking a random action
# [0.25091893 0.24943123 0.25002275 0.24962709]
# Exploring: Taking a random action
# [0.25089384 0.24940629 0.25009774 0.24960213]
# Exploring: Taking a random action
# [0.25086876 0.24938135 0.25017272 0.24957717]
# Exploring: Taking a random action
# [0.25084367 0.24935642 0.25014771 0.2496522 ]
# Exploring: Taking a random action
# [0.25081859 0.24943147 0.2501227  0.24962724]
# Exploring: Taking a random action
# [0.25079351 0.24940653 0.25019768 0.24960228]
# Exploring: Taking a random action
# [0.25076843 0.24938159 0.25027265 0.24957732]
# Exploring: Taking a random action
# [0.25074336 0.24945665 0.25024762 0.24955237]
# Exploring: Taking a random action
# [0.25071829 0.24943171 0.25032259 0.24952742]
# Exploring: Taking a random action
# [0.25069322 0.24950676 0.25029756 0.24950247]
# Exploring: Taking a random action
# [0.25066815 0.24948181 0.25037253 0.24947752]
# Exploring: Taking a random action
# [0.25064309 0.24945686 0.25034749 0.24955256]
# Exploring: Taking a random action
# [0.25071801 0.24943192 0.25032246 0.24952761]
# Exploring: Taking a random action
# [0.25069295 0.24950697 0.25029743 0.24950266]
# Exploring: Taking a random action
# [0.25076787 0.24948202 0.2502724  0.24947771]
# Exploring: Taking a random action
# [0.25084278 0.24945707 0.25024738 0.24945277]
# Exploring: Taking a random action
# [0.25091769 0.24943213 0.25022235 0.24942782]
# Exploring: Taking a random action
# [0.2508926  0.24940719 0.25029732 0.24940288]
# Exploring: Taking a random action
# [0.25086752 0.24938225 0.2502723  0.24947794]
# Exploring: Taking a random action
# [0.25084243 0.24945731 0.25024727 0.24945299]
# Episode 3: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25091734 0.24943236 0.25022225 0.24942805]
# Exploring: Taking a random action
# [0.25089225 0.24940742 0.25029722 0.24940311]
# Exploring: Taking a random action
# [0.25086716 0.24938248 0.25037218 0.24937817]
# Exploring: Taking a random action
# [0.25094207 0.24935755 0.25034715 0.24935323]
# Exploring: Taking a random action
# [0.25091698 0.2494326  0.25032212 0.2493283 ]
# Exploring: Taking a random action
# [0.25089189 0.24940766 0.25039708 0.24930337]
# Exploring: Taking a random action
# [0.2508668  0.24938273 0.25037204 0.24937843]
# Exploring: Taking a random action
# [0.25084172 0.24935779 0.250447   0.2493535 ]
# Exploring: Taking a random action
# [0.25081664 0.24933286 0.25042195 0.24942855]
# Exploring: Taking a random action
# [0.25079156 0.24930793 0.2504969  0.24940361]
# Exploring: Taking a random action
# [0.25076648 0.249283   0.25047186 0.24947867]
# Exploring: Taking a random action
# [0.25074141 0.24935806 0.25044681 0.24945372]
# Exploring: Taking a random action
# [0.25071634 0.24933313 0.25042177 0.24952877]
# Exploring: Taking a random action
# [0.25069127 0.2493082  0.25039673 0.24960381]
# Exploring: Taking a random action
# [0.2506662  0.24928327 0.25047168 0.24957885]
# Exploiting: Taking the best-known action
# [0.25064114 0.24935833 0.25044664 0.24955389]
# Exploring: Taking a random action
# [0.25007499 0.249975   0.249975   0.249975  ]
# Exploring: Taking a random action
# [0.25004999 0.25005    0.24995001 0.24995001]
# Exploring: Taking a random action
# [0.25002499 0.25012499 0.24992501 0.24992501]
# Exploring: Taking a random action
# [0.24999999 0.25009998 0.25000001 0.24990002]
# Exploring: Taking a random action
# [0.24997499 0.25007497 0.24997502 0.24997503]
# Exploring: Taking a random action
# [0.24994999 0.25014995 0.24995002 0.24995003]
# Exploring: Taking a random action
# [0.249925   0.25012494 0.24992503 0.25002503]
# Exploring: Taking a random action
# [0.25       0.25009993 0.24990004 0.25000003]
# Exploiting: Taking the best-known action
# [0.249975   0.25007492 0.24997504 0.24997503]
# Exploring: Taking a random action
# [0.24995001 0.25004992 0.24995005 0.25005003]
# Exploring: Taking a random action
# [0.24992502 0.25012491 0.24992505 0.25002502]
# Exploring: Taking a random action
# [0.24990003 0.2500999  0.25000005 0.25000002]
# Exploring: Taking a random action
# [0.24987504 0.25017488 0.24997506 0.24997503]
# Exploring: Taking a random action
# [0.24985005 0.25014986 0.25005005 0.24995003]
# Exploring: Taking a random action
# [0.24992506 0.25012485 0.25002505 0.24992504]
# Exploring: Taking a random action
# [0.25000006 0.25009984 0.25000005 0.24990005]
# Exploring: Taking a random action
# [0.24997506 0.25007483 0.24997505 0.24997505]
# Exploring: Taking a random action
# [0.25005006 0.25004983 0.24995006 0.24995006]
# Exploring: Taking a random action
# [0.25012504 0.25002483 0.24992506 0.24992506]
# Exploring: Taking a random action
# [0.25010003 0.24999983 0.25000006 0.24990007]
# Exploring: Taking a random action
# [0.25007503 0.24997483 0.25007506 0.24987509]
# Exploring: Taking a random action
# [0.25015001 0.24994983 0.25005005 0.2498501 ]
# Exploring: Taking a random action
# [0.250125   0.24992484 0.25002505 0.24992511]
# Exploring: Taking a random action
# [0.25019998 0.24989985 0.25000005 0.24990012]
# Exploring: Taking a random action
# [0.25017496 0.24997485 0.24997505 0.24987513]
# Exploring: Taking a random action
# [0.25014995 0.24994986 0.24995006 0.24995014]
# Exploring: Taking a random action
# [0.25012493 0.24992487 0.24992506 0.25002513]
# Exploring: Taking a random action
# [0.25009992 0.24999987 0.24990007 0.25000013]
# Exploring: Taking a random action
# [0.25017491 0.24997487 0.24987509 0.24997514]
# Exploring: Taking a random action
# [0.25014989 0.24994987 0.2498501  0.25005013]
# Exploring: Taking a random action
# [0.25012488 0.25002487 0.24982512 0.25002513]
# Exploring: Taking a random action
# [0.25009987 0.24999987 0.24990013 0.25000013]
# Exploring: Taking a random action
# [0.25007486 0.25007486 0.24987514 0.24997513]
# Exploring: Taking a random action
# [0.25004986 0.25004986 0.24995015 0.24995014]
# Episode 4: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25061607 0.24943339 0.2504216  0.24952894]
# Exploring: Taking a random action
# [0.250691   0.24940845 0.25039656 0.24950399]
# Exploring: Taking a random action
# [0.25066594 0.24938351 0.25047151 0.24947904]
# Exploring: Taking a random action
# [0.25064087 0.24935857 0.25054645 0.2494541 ]
# Exploring: Taking a random action
# [0.25061581 0.24933364 0.25062139 0.24942915]
# Exploring: Taking a random action
# [0.25059075 0.24930871 0.25069632 0.24940421]
# Exploring: Taking a random action
# [0.2505657  0.24928378 0.25077125 0.24937928]
# Exploring: Taking a random action
# [0.25064063 0.24925886 0.25074617 0.24935434]
# Exploring: Taking a random action
# [0.25061557 0.24923393 0.25082109 0.24932941]
# Exploring: Taking a random action
# [0.25059051 0.249309   0.25079601 0.24930448]
# Exploring: Taking a random action
# [0.25066545 0.24928407 0.25077093 0.24927955]
# Exploiting: Taking the best-known action
# [0.25064038 0.24935914 0.25074586 0.24925462]
# Exploring: Taking a random action
# [0.25002486 0.25002486 0.25002514 0.24992514]
# Exploring: Taking a random action
# [0.24999986 0.24999986 0.25010013 0.24990015]
# Exploring: Taking a random action
# [0.24997486 0.24997486 0.25017512 0.24987517]
# Exploring: Taking a random action
# [0.24994986 0.24994986 0.25025009 0.24985018]
# Exploring: Taking a random action
# [0.24992487 0.24992487 0.25032506 0.2498252 ]
# Exploiting: Taking the best-known action
# [0.24967519 0.2496752  0.25007498 0.25057463]
# Exploring: Taking a random action
# [0.24975025 0.24975025 0.24975025 0.25074925]
# Exploring: Taking a random action
# [0.24950075 0.24950075 0.25049975 0.25049875]
# Exploring: Taking a random action
# [0.2492515 0.2492515 0.2502495 0.2512475]
# Exploring: Taking a random action
# [0.2500015  0.2490025  0.2499995  0.25099651]
# Exploring: Taking a random action
# [0.24975174 0.24975274 0.24974975 0.25074576]
# Exploring: Taking a random action
# [0.25050124 0.24950324 0.24950025 0.25049527]
# Exploring: Taking a random action
# [0.2504762  0.24947829 0.24957529 0.25047022]
# Exploring: Taking a random action
# [0.24975022 0.24965023 0.25004998 0.25054957]
# Exploring: Taking a random action
# [0.24972525 0.24962527 0.25012497 0.25052452]
# Exploring: Taking a random action
# [0.24970028 0.2497003  0.25009996 0.25049947]
# Exploring: Taking a random action
# [0.2497753  0.24967533 0.25007495 0.25047442]
# Exploring: Taking a random action
# [0.24985031 0.24965037 0.25004994 0.25044938]
# Exploring: Taking a random action
# [0.24982533 0.24972539 0.25002494 0.25042433]
# Exploring: Taking a random action
# [0.24980035 0.24970042 0.25009993 0.25039929]
# Exploring: Taking a random action
# [0.24987536 0.24967545 0.25007492 0.25037426]
# Exploiting: Taking the best-known action
# [0.24985038 0.24975048 0.25004992 0.25034922]
# Exploring: Taking a random action
# [0.249975   0.25007499 0.249975   0.249975  ]
# Exploring: Taking a random action
# [0.25005    0.25004999 0.24995001 0.24995001]
# Exploring: Taking a random action
# [0.250025   0.25012498 0.24992501 0.24992501]
# Exploring: Taking a random action
# [0.25009999 0.25009997 0.24990002 0.24990002]
# Exploring: Taking a random action
# [0.25007498 0.25017495 0.24987504 0.24987504]
# Exploiting: Taking the best-known action
# [0.25004997 0.25014993 0.24995004 0.24985005]
# Exploring: Taking a random action
# [0.25002497 0.25012492 0.24992505 0.24992506]
# Exploring: Taking a random action
# [0.24999997 0.2501999  0.24990006 0.24990007]
# Exploring: Taking a random action
# [0.24997497 0.25027487 0.24987507 0.24987508]
# Exploring: Taking a random action
# [0.24994998 0.25024985 0.24985009 0.24995009]
# Exploring: Taking a random action
# [0.24992499 0.25032482 0.2498251  0.24992509]
# Exploring: Taking a random action
# [0.2499     0.25029979 0.24980012 0.25000009]
# Exploring: Taking a random action
# [0.24987501 0.25027476 0.24987514 0.2499751 ]
# Exploring: Taking a random action
# [0.24985002 0.25024973 0.24995014 0.2499501 ]
# Exploring: Taking a random action
# [0.24982504 0.25022471 0.24992515 0.2500251 ]
# Exploring: Taking a random action
# [0.24990005 0.25019969 0.24990016 0.2500001 ]
# Episode 5: Did not reach the goal. Total reward: -1.13
# Exploring: Taking a random action
# [0.25061532 0.24943419 0.25072079 0.2492297 ]
# Exploring: Taking a random action
# [0.25059026 0.24940925 0.25069572 0.24930477]
# Exploring: Taking a random action
# [0.25066519 0.24938431 0.25067065 0.24927984]
# Exploring: Taking a random action
# [0.25074012 0.24935938 0.25064558 0.24925492]
# Exploring: Taking a random action
# [0.25071505 0.24933445 0.25062052 0.24932998]
# Exploring: Taking a random action
# [0.25068998 0.2494095  0.25059546 0.24930505]
# Exploring: Taking a random action
# [0.25066491 0.24938457 0.25057041 0.24938012]
# Exploring: Taking a random action
# [0.25063985 0.24935963 0.25054535 0.24945517]
# Exploiting: Taking the best-known action
# [0.25061479 0.24943469 0.2505203  0.24943023]
# Exploring: Taking a random action
# [0.2498254  0.24972551 0.25002492 0.25042418]
# Exploring: Taking a random action
# [0.24980042 0.24970054 0.25009991 0.25039914]
# Exploring: Taking a random action
# [0.24977544 0.24977556 0.2500749  0.2503741 ]
# Exploring: Taking a random action
# [0.24985045 0.24975058 0.25004989 0.25034907]
# Exploring: Taking a random action
# [0.24982547 0.24972561 0.25012488 0.25032403]
# Exploring: Taking a random action
# [0.24980049 0.24970064 0.25009987 0.25039899]
# Exploring: Taking a random action
# [0.24977551 0.24967567 0.25017485 0.25037396]
# Exploring: Taking a random action
# [0.24975054 0.24965071 0.25014984 0.25044891]
# Exploring: Taking a random action
# [0.24982556 0.24962575 0.25012483 0.25042387]
# Exploring: Taking a random action
# [0.24980058 0.24960079 0.25009982 0.25049882]
# Exploring: Taking a random action
# [0.24987559 0.24957583 0.25007481 0.25047377]
# Exploring: Taking a random action
# [0.2498506  0.24955087 0.2500498  0.25054872]
# Exploring: Taking a random action
# [0.24992561 0.24952592 0.2500248  0.25052366]
# Exploring: Taking a random action
# [0.24990062 0.24950097 0.2499998  0.2505986 ]
# Exploring: Taking a random action
# [0.24997562 0.24947602 0.24997481 0.25057355]
# Exploring: Taking a random action
# [0.24995063 0.24955107 0.24994981 0.25054849]
# Exploring: Taking a random action
# [0.24992564 0.24952612 0.24992482 0.25062343]
# Exploring: Taking a random action
# [0.24990065 0.24950117 0.24999982 0.25059837]
# Exploiting: Taking the best-known action
# [0.24987566 0.24957621 0.24997482 0.25057331]
# Exploring: Taking a random action
# [0.24987506 0.25017467 0.24987517 0.25007509]
# Exploring: Taking a random action
# [0.24985008 0.25014966 0.24985019 0.25015008]
# Exploring: Taking a random action
# [0.24982509 0.25022464 0.2498252  0.25012506]
# Exploring: Taking a random action
# [0.24980011 0.25019962 0.24990021 0.25010005]
# Exploring: Taking a random action
# [0.24977514 0.2501746  0.24997522 0.25007505]
# Exploring: Taking a random action
# [0.24975016 0.25014958 0.24995022 0.25015003]
# Exploring: Taking a random action
# [0.24972519 0.25012457 0.25002522 0.25012502]
# Exploring: Taking a random action
# [0.24970022 0.25009956 0.25000022 0.2502    ]
# Exploring: Taking a random action
# [0.24967525 0.25007455 0.24997522 0.25027497]
# Exploring: Taking a random action
# [0.24965029 0.25014954 0.24995023 0.25024995]
# Exploring: Taking a random action
# [0.24962532 0.25012453 0.24992523 0.25032491]
# Exploring: Taking a random action
# [0.24970035 0.25009952 0.24990024 0.25029988]
# Exploring: Taking a random action
# [0.24977538 0.25007451 0.24987526 0.25027486]
# Exploring: Taking a random action
# [0.2497504  0.2500495  0.24985027 0.25034982]
# Exploring: Taking a random action
# [0.24972543 0.2500245  0.24982529 0.25042478]
# Exploring: Taking a random action
# [0.24980045 0.2499995  0.24980031 0.25039974]
# Exploring: Taking a random action
# [0.24977547 0.2499745  0.24977533 0.25047469]
# Exploring: Taking a random action
# [0.24985049 0.24994951 0.24975036 0.25044965]
# Exploring: Taking a random action
# [0.24992549 0.24992452 0.24972538 0.25042461]
# Exploiting: Taking the best-known action
# [0.2499005  0.24989953 0.2498004  0.25039957]
# Exploring: Taking a random action
# [0.24997551 0.24987454 0.24977543 0.25037453]
# Exploring: Taking a random action
# [0.24995051 0.24994954 0.24975045 0.25034949]
# Episode 6: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25058973 0.24940975 0.25049525 0.24950528]
# Exploring: Taking a random action
# [0.25066466 0.24938481 0.2504702  0.24948033]
# Exploring: Taking a random action
# [0.25073959 0.24935987 0.25044516 0.24945538]
# Exploring: Taking a random action
# [0.25081451 0.24933494 0.25042012 0.24943044]
# Exploring: Taking a random action
# [0.25078943 0.24931001 0.25049507 0.2494055 ]
# Exploring: Taking a random action
# [0.25076435 0.24928508 0.25047002 0.24948055]
# Exploring: Taking a random action
# [0.25073928 0.24936014 0.25044497 0.24945561]
# Exploring: Taking a random action
# [0.25071421 0.24933521 0.25051992 0.24943066]
# Exploring: Taking a random action
# [0.25068914 0.24941027 0.25049487 0.24940572]
# Exploring: Taking a random action
# [0.25076406 0.24938533 0.25046983 0.24938078]
# Exploiting: Taking the best-known action
# [0.25073899 0.24946038 0.25044478 0.24935585]
# Exploring: Taking a random action
# [0.24995066 0.24955125 0.24994983 0.25054826]
# Exploring: Taking a random action
# [0.24992567 0.2495263  0.25002482 0.25052321]
# Exploring: Taking a random action
# [0.25000067 0.24950135 0.24999982 0.25049816]
# Exploiting: Taking the best-known action
# [0.24997567 0.24957639 0.24997483 0.25047311]
# Exploring: Taking a random action
# [0.24992552 0.24992455 0.24982547 0.25032446]
# Exploring: Taking a random action
# [0.24990053 0.24999955 0.24980049 0.25029943]
# Exploring: Taking a random action
# [0.24987554 0.24997455 0.2498755  0.2502744 ]
# Exploring: Taking a random action
# [0.24985056 0.24994956 0.24985052 0.25034937]
# Exploring: Taking a random action
# [0.24982557 0.24992457 0.24982553 0.25042433]
# Exploring: Taking a random action
# [0.24990058 0.24989958 0.24980055 0.25039929]
# Exploring: Taking a random action
# [0.2498756  0.24997458 0.24977558 0.25037425]
# Exploring: Taking a random action
# [0.24985061 0.24994958 0.2497506  0.2504492 ]
# Exploring: Taking a random action
# [0.24982563 0.24992459 0.24982562 0.25042416]
# Exploring: Taking a random action
# [0.24980065 0.2498996  0.24980064 0.25049911]
# Exploring: Taking a random action
# [0.24987566 0.24987461 0.24977566 0.25047406]
# Exploring: Taking a random action
# [0.24985068 0.24994962 0.24975069 0.25044902]
# Exploring: Taking a random action
# [0.24982569 0.24992463 0.24972571 0.25052397]
# Exploring: Taking a random action
# [0.24980071 0.24999963 0.24970074 0.25049892]
# Exploring: Taking a random action
# [0.24977574 0.24997463 0.24967578 0.25057386]
# Exploring: Taking a random action
# [0.24985075 0.24994963 0.24965081 0.2505488 ]
# Exploring: Taking a random action
# [0.24992576 0.24992464 0.24962585 0.25052375]
# Exploring: Taking a random action
# [0.24990077 0.24999964 0.24960089 0.2504987 ]
# Exploring: Taking a random action
# [0.24987578 0.25007463 0.24957593 0.25047365]
# Exploring: Taking a random action
# [0.24995079 0.25004963 0.24955098 0.25044861]
# Exploring: Taking a random action
# [0.24992579 0.25002463 0.24952602 0.25052356]
# Exploring: Taking a random action
# [0.2499008  0.24999963 0.24960106 0.25049851]
# Exploiting: Taking the best-known action
# [0.24987582 0.24997463 0.2496761  0.25047346]
# Exploiting: Taking the best-known action
# [0.24985083 0.24994963 0.24975112 0.25044842]
# Exploring: Taking a random action
# [0.24982585 0.24992464 0.24972615 0.25052336]
# Exploring: Taking a random action
# [0.24980087 0.24999964 0.24970118 0.25049831]
# Exploring: Taking a random action
# [0.24977589 0.24997464 0.2497762  0.25047327]
# Exploiting: Taking the best-known action
# [0.2498509  0.24994965 0.24975122 0.25044822]
# Exploring: Taking a random action
# [0.25005067 0.24955144 0.24994983 0.25044806]
# Exploring: Taking a random action
# [0.25012566 0.24952649 0.24992484 0.25042302]
# Exploring: Taking a random action
# [0.25010065 0.24960152 0.24989985 0.25039798]
# Exploring: Taking a random action
# [0.25007564 0.24957657 0.24987486 0.25047293]
# Exploring: Taking a random action
# [0.25005063 0.24955161 0.24994987 0.25044789]
# Exploring: Taking a random action
# [0.25002563 0.24952666 0.25002486 0.25042285]
# Exploiting: Taking the best-known action
# [0.25000063 0.2496017  0.24999986 0.25039781]
# Episode 7: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25071392 0.24953543 0.25041974 0.24933092]
# Exploring: Taking a random action
# [0.25068885 0.24951048 0.25049469 0.24930598]
# Exploring: Taking a random action
# [0.25066378 0.24958552 0.25046964 0.24928106]
# Exploring: Taking a random action
# [0.25063872 0.24966055 0.2504446  0.24925613]
# Exploring: Taking a random action
# [0.25061366 0.24963559 0.25041956 0.2493312 ]
# Exploring: Taking a random action
# [0.25068859 0.24961063 0.25039452 0.24930627]
# Exploring: Taking a random action
# [0.25066352 0.24958567 0.25036948 0.24938133]
# Exploiting: Taking the best-known action
# [0.25063846 0.2496607  0.25034445 0.24935639]
# Exploring: Taking a random action
# [0.24997563 0.24957674 0.25007486 0.25037277]
# Exploring: Taking a random action
# [0.24995064 0.24955179 0.25014984 0.25034774]
# Exploring: Taking a random action
# [0.24992565 0.24962682 0.25012483 0.2503227 ]
# Exploring: Taking a random action
# [0.24990066 0.24970185 0.25009982 0.25029767]
# Exploring: Taking a random action
# [0.24997566 0.24967689 0.25007481 0.25027265]
# Exploring: Taking a random action
# [0.24995066 0.24965192 0.2501498  0.25024762]
# Exploiting: Taking the best-known action
# [0.24992567 0.24972695 0.25012478 0.2502226 ]
# Exploring: Taking a random action
# [0.24982592 0.24992466 0.24972625 0.25052317]
# Exploring: Taking a random action
# [0.24990093 0.24989967 0.24970128 0.25049812]
# Exploring: Taking a random action
# [0.24997593 0.24987468 0.24967631 0.25047307]
# Exploring: Taking a random action
# [0.24995094 0.24984969 0.24975134 0.25044803]
# Exploring: Taking a random action
# [0.24992595 0.24982471 0.24972637 0.25052297]
# Exploiting: Taking the best-known action
# [0.24990096 0.24989972 0.2497014  0.25049792]
# Exploring: Taking a random action
# [0.25007499 0.249975   0.249975   0.249975  ]
# Exploring: Taking a random action
# [0.25004999 0.24995001 0.24995001 0.25005   ]
# Exploring: Taking a random action
# [0.25002499 0.24992501 0.24992501 0.25012499]
# Exploring: Taking a random action
# [0.24999999 0.24990002 0.24990002 0.25019997]
# Exploring: Taking a random action
# [0.24997499 0.24997503 0.24987504 0.25017495]
# Exploring: Taking a random action
# [0.24994999 0.25005002 0.24985005 0.25014993]
# Exploring: Taking a random action
# [0.249925   0.25012501 0.24982507 0.25012492]
# Exploring: Taking a random action
# [0.24990001 0.25019999 0.24980009 0.25009991]
# Exploiting: Taking the best-known action
# [0.24987502 0.25017497 0.2498751  0.2500749 ]
# Exploring: Taking a random action
# [0.24995003 0.25014996 0.24985012 0.2500499 ]
# Exploring: Taking a random action
# [0.24992503 0.25012495 0.24992512 0.2500249 ]
# Exploring: Taking a random action
# [0.24990004 0.25009994 0.24990013 0.25009989]
# Exploring: Taking a random action
# [0.24987506 0.25007493 0.24997514 0.25007488]
# Exploring: Taking a random action
# [0.24985007 0.25014991 0.24995014 0.25004987]
# Exploiting: Taking the best-known action
# [0.24992508 0.2501249  0.24992515 0.25002487]
# Exploring: Taking a random action
# [0.24987597 0.24987474 0.24967643 0.25057287]
# Exploring: Taking a random action
# [0.24985098 0.24994974 0.24965146 0.25054781]
# Exploring: Taking a random action
# [0.249826   0.24992475 0.2496265  0.25062275]
# Exploring: Taking a random action
# [0.24980102 0.24989976 0.24960154 0.25069768]
# Exploring: Taking a random action
# [0.24977604 0.24987477 0.24957658 0.2507726 ]
# Exploring: Taking a random action
# [0.24975107 0.24994978 0.24955163 0.25074753]
# Exploring: Taking a random action
# [0.2497261  0.24992478 0.24962667 0.25072246]
# Exploiting: Taking the best-known action
# [0.24970113 0.24999978 0.2496017  0.25069739]
# Exploring: Taking a random action
# [0.24990009 0.25009989 0.24990016 0.25009986]
# Exploring: Taking a random action
# [0.2498751  0.25007488 0.24987517 0.25017484]
# Exploring: Taking a random action
# [0.24985012 0.25014987 0.24985019 0.25014983]
# Exploring: Taking a random action
# [0.24992512 0.25012486 0.2498252  0.25012482]
# Exploiting: Taking the best-known action
# [0.24990013 0.25009985 0.24990021 0.25009981]
# Exploring: Taking a random action
# [0.24987515 0.25017483 0.24987523 0.2500748 ]
# Episode 8: Did not reach the goal. Total reward: -0.50
# Exploiting: Taking the best-known action
# [0.25061339 0.24973573 0.25031941 0.24933146]
# Exploring: Taking a random action
# [0.24990068 0.24970198 0.25009977 0.25029757]
# Exploring: Taking a random action
# [0.24987569 0.24967701 0.25007477 0.25037253]
# Exploring: Taking a random action
# [0.24985071 0.24975203 0.25004976 0.2503475 ]
# Exploring: Taking a random action
# [0.24992571 0.24972706 0.25002476 0.25032247]
# Exploring: Taking a random action
# [0.25000071 0.24970209 0.24999976 0.25029744]
# Exploiting: Taking the best-known action
# [0.24997572 0.24977711 0.24997476 0.25027241]
# Exploring: Taking a random action
# [0.24967616 0.24997479 0.24957675 0.25077231]
# Exploring: Taking a random action
# [0.24965119 0.24994979 0.24955179 0.25084722]
# Exploring: Taking a random action
# [0.24962623 0.2499248  0.24952684 0.25092213]
# Exploiting: Taking the best-known action
# [0.24960127 0.2499998  0.24950189 0.25089704]
# Exploiting: Taking the best-known action
# [0.24985016 0.25014981 0.24995023 0.25004979]
# Exploring: Taking a random action
# [0.24982518 0.2501248  0.25002523 0.25002479]
# Exploiting: Taking the best-known action
# [0.24990019 0.25009979 0.25000023 0.24999979]
# Exploring: Taking a random action
# [0.24957631 0.25007479 0.24947694 0.25087196]
# Exploring: Taking a random action
# [0.24955136 0.25004979 0.24955199 0.25084687]
# Exploring: Taking a random action
# [0.24952641 0.25002478 0.24962702 0.25082179]
# Exploiting: Taking the best-known action
# [0.24960144 0.24999978 0.24960206 0.25079671]
# Exploring: Taking a random action
# [0.24995072 0.24975214 0.24994977 0.25034737]
# Exploring: Taking a random action
# [0.24992573 0.24982716 0.24992477 0.25032234]
# Exploring: Taking a random action
# [0.24990074 0.24980218 0.24999977 0.25029731]
# Exploring: Taking a random action
# [0.24987575 0.24987719 0.24997478 0.25027228]
# Exploring: Taking a random action
# [0.24985077 0.2498522  0.25004977 0.25024726]
# Exploring: Taking a random action
# [0.24992577 0.24982722 0.25002477 0.25022224]
# Exploring: Taking a random action
# [0.25000077 0.24980224 0.24999977 0.25019722]
# Exploiting: Taking the best-known action
# [0.24997578 0.24987725 0.24997477 0.2501722 ]
# Exploiting: Taking the best-known action
# [0.24957649 0.25007478 0.24957711 0.25077163]
# Exploring: Taking a random action
# [0.24997519 0.25007478 0.24997523 0.24997479]
# Exploring: Taking a random action
# [0.2499502  0.25004978 0.25005023 0.2499498 ]
# Exploring: Taking a random action
# [0.2499252  0.25002478 0.25002522 0.2500248 ]
# Exploring: Taking a random action
# [0.24990021 0.24999978 0.25010021 0.2499998 ]
# Exploring: Taking a random action
# [0.24987523 0.25007477 0.25007521 0.2499748 ]
# Exploring: Taking a random action
# [0.24985024 0.25004976 0.2500502  0.25004979]
# Exploring: Taking a random action
# [0.24982526 0.25012475 0.2500252  0.25002479]
# Exploring: Taking a random action
# [0.24980028 0.25019973 0.2500002  0.24999979]
# Exploring: Taking a random action
# [0.2497753  0.25017471 0.25007519 0.24997479]
# Exploring: Taking a random action
# [0.24975033 0.25024969 0.25005019 0.2499498 ]
# Exploring: Taking a random action
# [0.24972535 0.25022467 0.25002518 0.2500248 ]
# Exploring: Taking a random action
# [0.24970038 0.25019965 0.25010017 0.2499998 ]
# Exploring: Taking a random action
# [0.24977541 0.25017463 0.25007517 0.2499748 ]
# Exploring: Taking a random action
# [0.24975043 0.25014961 0.25005016 0.25004979]
# Exploring: Taking a random action
# [0.24982545 0.2501246  0.25002516 0.25002479]
# Exploring: Taking a random action
# [0.24980047 0.25009959 0.25010015 0.24999979]
# Exploring: Taking a random action
# [0.24977549 0.25007458 0.25007514 0.25007478]
# Exploring: Taking a random action
# [0.24985051 0.25004958 0.25005014 0.25004978]
# Exploring: Taking a random action
# [0.24982552 0.25002458 0.25002513 0.25012477]
# Exploring: Taking a random action
# [0.24980054 0.24999958 0.25010012 0.25009976]
# Exploiting: Taking the best-known action
# [0.24977557 0.25007457 0.25007512 0.25007475]
# Exploiting: Taking the best-known action
# [0.25007499 0.249975   0.249975   0.249975  ]
# Exploiting: Taking the best-known action
# [0.24975059 0.25014955 0.25005011 0.25004974]
# Episode 9: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25058834 0.24971076 0.25029438 0.24940652]
# Exploring: Taking a random action
# [0.25056328 0.24968579 0.25036935 0.24938158]
# Exploring: Taking a random action
# [0.25053823 0.24966083 0.2504443  0.24935665]
# Exploring: Taking a random action
# [0.25051317 0.24973585 0.25041926 0.24933171]
# Exploring: Taking a random action
# [0.25058812 0.24971088 0.25039422 0.24930678]
# Exploring: Taking a random action
# [0.25056306 0.24968591 0.25036918 0.24938184]
# Exploring: Taking a random action
# [0.250638   0.24966095 0.25034415 0.24935691]
# Exploring: Taking a random action
# [0.25071292 0.24963598 0.25031912 0.24933198]
# Exploring: Taking a random action
# [0.25078785 0.24961102 0.25029409 0.24930704]
# Exploring: Taking a random action
# [0.25076277 0.24958606 0.25026906 0.24938211]
# Exploring: Taking a random action
# [0.2507377  0.2496611  0.25024404 0.24935717]
# Exploring: Taking a random action
# [0.25071262 0.24973612 0.25021902 0.24933224]
# Exploring: Taking a random action
# [0.25068756 0.24971115 0.250194   0.2494073 ]
# Exploring: Taking a random action
# [0.25076248 0.24968618 0.25016898 0.24938236]
# Exploring: Taking a random action
# [0.2508374  0.24966122 0.25014397 0.24935742]
# Exploiting: Taking the best-known action
# [0.25081231 0.24973624 0.25011895 0.24933249]
# Exploring: Taking a random action
# [0.24995078 0.24985227 0.25004977 0.25014719]
# Exploring: Taking a random action
# [0.24992579 0.24992727 0.25002476 0.25012217]
# Exploring: Taking a random action
# [0.2499008  0.24990228 0.24999976 0.25019715]
# Exploiting: Taking the best-known action
# [0.24987581 0.24997729 0.24997477 0.25017214]
# Exploring: Taking a random action
# [0.24965152 0.25004977 0.24955215 0.25074656]
# Exploring: Taking a random action
# [0.24962656 0.25002477 0.24962719 0.25072148]
# Exploring: Taking a random action
# [0.24970159 0.24999977 0.24960223 0.25069642]
# Exploring: Taking a random action
# [0.24967662 0.25007476 0.24957727 0.25067135]
# Exploring: Taking a random action
# [0.24965166 0.25014975 0.24955231 0.25064628]
# Exploring: Taking a random action
# [0.24962669 0.25012473 0.24952736 0.25072121]
# Exploring: Taking a random action
# [0.24960173 0.25009972 0.24950241 0.25079613]
# Exploring: Taking a random action
# [0.24957678 0.25007472 0.24957745 0.25077105]
# Exploring: Taking a random action
# [0.24955182 0.2501497  0.2495525  0.25074598]
# Exploring: Taking a random action
# [0.24952687 0.25022468 0.24952755 0.25072091]
# Exploring: Taking a random action
# [0.24950192 0.25019966 0.24960259 0.25069584]
# Exploring: Taking a random action
# [0.24947697 0.25017464 0.24957763 0.25077076]
# Exploiting: Taking the best-known action
# [0.24955201 0.25014963 0.24955267 0.25074569]
# Exploring: Taking a random action
# [0.24985083 0.25005228 0.24994977 0.25014712]
# Exploring: Taking a random action
# [0.24992583 0.25002728 0.24992478 0.25012211]
# Exploiting: Taking the best-known action
# [0.24990084 0.25000228 0.24999978 0.2500971 ]
# Exploring: Taking a random action
# [0.24987586 0.24997728 0.25007477 0.25007209]
# Exploiting: Taking the best-known action
# [0.24962623 0.24972755 0.24982495 0.25082127]
# Exploring: Taking a random action
# [0.25045115 0.24945335 0.24965033 0.25044518]
# Exploring: Taking a random action
# [0.24960127 0.24970258 0.24979997 0.25089618]
# Exploring: Taking a random action
# [0.24957631 0.24967762 0.24977499 0.25097108]
# Exploiting: Taking the best-known action
# [0.24965135 0.24965265 0.24975001 0.25094599]
# Exploring: Taking a random action
# [0.25078724 0.24971127 0.25019393 0.24930756]
# Exploring: Taking a random action
# [0.25076216 0.2496863  0.25016892 0.24938262]
# Exploring: Taking a random action
# [0.25073709 0.24966134 0.25024389 0.24935768]
# Exploring: Taking a random action
# [0.250812   0.24963637 0.25021887 0.24933275]
# Exploring: Taking a random action
# [0.25078693 0.24961141 0.25019385 0.24940781]
# Exploring: Taking a random action
# [0.25076185 0.24958645 0.25016883 0.24948286]
# Exploring: Taking a random action
# [0.25083677 0.2495615  0.25014382 0.24945792]
# Exploring: Taking a random action
# [0.25081168 0.24953654 0.2502188  0.24943297]
# Episode 10: Did not reach the goal. Total reward: -0.59
# Exploring: Taking a random action
# [0.25078661 0.24951159 0.25019378 0.24950802]
# Exploring: Taking a random action
# [0.25076153 0.24958663 0.25016876 0.24948307]
# Exploring: Taking a random action
# [0.25073646 0.24956168 0.25014375 0.24955812]
# Exploiting: Taking the best-known action
# [0.25071139 0.24963671 0.25011874 0.24953316]
# Exploring: Taking a random action
# [0.24962638 0.24972768 0.24972504 0.2509209 ]
# Exploring: Taking a random action
# [0.24960142 0.24970271 0.24980006 0.25089581]
# Exploring: Taking a random action
# [0.24957647 0.24967774 0.24977508 0.25097071]
# Exploring: Taking a random action
# [0.24955151 0.24965277 0.2498501  0.25094562]
# Exploring: Taking a random action
# [0.24952656 0.24962781 0.24992511 0.25092052]
# Exploring: Taking a random action
# [0.24950161 0.24960285 0.25000011 0.25089544]
# Exploring: Taking a random action
# [0.24947666 0.24957789 0.2500751  0.25087035]
# Exploring: Taking a random action
# [0.24945172 0.24955294 0.25015008 0.25084526]
# Exploring: Taking a random action
# [0.24942677 0.24952798 0.25012507 0.25092017]
# Exploring: Taking a random action
# [0.24940183 0.24960302 0.25010006 0.25089508]
# Exploring: Taking a random action
# [0.24937689 0.24957807 0.25017504 0.25087   ]
# Exploring: Taking a random action
# [0.24935196 0.2496531  0.25015003 0.25084491]
# Exploring: Taking a random action
# [0.24932703 0.24962814 0.25012502 0.25091982]
# Exploring: Taking a random action
# [0.2493021  0.24960318 0.2502     0.25089473]
# Exploring: Taking a random action
# [0.24937716 0.24957822 0.25017498 0.25086964]
# Exploring: Taking a random action
# [0.24945221 0.24955327 0.25014996 0.25084456]
# Exploring: Taking a random action
# [0.24942727 0.24952831 0.25022494 0.25081948]
# Exploring: Taking a random action
# [0.24950232 0.24950336 0.25019992 0.2507944 ]
# Exploiting: Taking the best-known action
# [0.24947737 0.2495784  0.2501749  0.25076932]
# Exploring: Taking a random action
# [0.24952706 0.2502246  0.24952772 0.25072061]
# Exploring: Taking a random action
# [0.2496021  0.25019958 0.24950277 0.25069555]
# Exploring: Taking a random action
# [0.24957714 0.25017457 0.24947782 0.25077047]
# Exploring: Taking a random action
# [0.24955219 0.25024954 0.24945288 0.25074539]
# Exploring: Taking a random action
# [0.24962723 0.25022452 0.24942793 0.25072032]
# Exploring: Taking a random action
# [0.24960227 0.2501995  0.24940299 0.25079524]
# Exploiting: Taking the best-known action
# [0.24957731 0.25017448 0.24947805 0.25077016]
# Exploring: Taking a random action
# [0.24955235 0.25014947 0.24955309 0.25074509]
# Exploring: Taking a random action
# [0.24962739 0.25012445 0.24952814 0.25072002]
# Exploring: Taking a random action
# [0.24960243 0.25009944 0.24950319 0.25079494]
# Exploring: Taking a random action
# [0.24957747 0.25007444 0.24957823 0.25076986]
# Exploiting: Taking the best-known action
# [0.24955252 0.25014942 0.24955327 0.25074479]
# Exploring: Taking a random action
# [0.24982561 0.25012454 0.25002511 0.25002474]
# Exploring: Taking a random action
# [0.24980063 0.25009953 0.25000011 0.25009973]
# Exploring: Taking a random action
# [0.24977565 0.25007452 0.2500751  0.25007472]
# Exploring: Taking a random action
# [0.24975068 0.25004952 0.2500501  0.25014971]
# Exploiting: Taking the best-known action
# [0.2497257  0.25012451 0.25002509 0.2501247 ]
# Exploring: Taking a random action
# [0.25004999 0.25005    0.24995001 0.24995001]
# Exploring: Taking a random action
# [0.25002499 0.25012499 0.24992501 0.24992501]
# Exploiting: Taking the best-known action
# [0.24999999 0.25009998 0.25000001 0.24990002]
# Exploiting: Taking the best-known action
# [0.24997499 0.25007497 0.24997502 0.24997503]
# Exploring: Taking a random action
# [0.249975   0.249975   0.249975   0.25007499]
# Exploring: Taking a random action
# [0.24995001 0.25005    0.24995001 0.25004999]
# Exploring: Taking a random action
# [0.24992501 0.25012499 0.24992501 0.25002499]
# Exploring: Taking a random action
# [0.24990002 0.25009998 0.25000001 0.24999999]
# Exploiting: Taking the best-known action
# [0.24997503 0.25007497 0.24997502 0.24997499]
# Exploiting: Taking the best-known action
# [0.25007499 0.249975   0.249975   0.249975  ]
# Episode 11: Did not reach the goal. Total reward: -0.50
# Exploring: Taking a random action
# [0.25068632 0.24961175 0.25019372 0.24950821]
# Exploiting: Taking the best-known action
# [0.25066125 0.24968678 0.2501687  0.24948327]
# Exploring: Taking a random action
# [0.24945243 0.24955345 0.25024988 0.25074424]
# Exploring: Taking a random action
# [0.24942749 0.2495285  0.25022486 0.25081916]
# Exploring: Taking a random action
# [0.24940254 0.24950355 0.25019984 0.25089407]
# Exploring: Taking a random action
# [0.24937761 0.2494786  0.25017482 0.25096898]
# Exploring: Taking a random action
# [0.24935267 0.24945365 0.2501498  0.25104387]
# Exploring: Taking a random action
# [0.24932774 0.24942871 0.25022478 0.25101877]
# Exploiting: Taking the best-known action
# [0.24930281 0.24950376 0.25019976 0.25099367]
# Exploring: Taking a random action
# [0.24952756 0.25012441 0.24962831 0.25071972]
# Exploring: Taking a random action
# [0.24950261 0.2500994  0.24960335 0.25079464]
# Exploring: Taking a random action
# [0.24947767 0.25007439 0.24967838 0.25076956]
# Exploring: Taking a random action
# [0.24955271 0.25004939 0.24965342 0.25074448]
# Exploring: Taking a random action
# [0.24952776 0.25002438 0.24972844 0.25071941]
# Exploring: Taking a random action
# [0.24950281 0.24999938 0.24970347 0.25079433]
# Exploiting: Taking the best-known action
# [0.24947786 0.25007438 0.24967851 0.25076926]
# Exploiting: Taking the best-known action
# [0.24970073 0.25019949 0.25000009 0.25009969]
# Exploring: Taking a random action
# [0.24994999 0.25004996 0.24995002 0.25005002]
# Exploring: Taking a random action
# [0.25002499 0.25002496 0.24992503 0.25002502]
# Exploring: Taking a random action
# [0.24999999 0.24999996 0.24990004 0.25010001]
# Exploring: Taking a random action
# [0.24997499 0.25007495 0.24987505 0.250075  ]
# Exploring: Taking a random action
# [0.24995    0.25004995 0.24985007 0.25014999]
# Exploring: Taking a random action
# [0.24992501 0.25012494 0.24982508 0.25012497]
# Exploring: Taking a random action
# [0.24990002 0.25009993 0.24990009 0.25009996]
# Exploring: Taking a random action
# [0.24987503 0.25017491 0.24987511 0.25007496]
# Exploring: Taking a random action
# [0.24985004 0.25014989 0.24985012 0.25014994]
# Exploiting: Taking the best-known action
# [0.24982506 0.25012488 0.24992513 0.25012493]
# Exploring: Taking a random action
# [0.24980008 0.25009987 0.24990014 0.25019991]
# Exploring: Taking a random action
# [0.2497751  0.25007486 0.24987515 0.25027488]
# Exploring: Taking a random action
# [0.24975013 0.25004986 0.24995016 0.25024986]
# Exploring: Taking a random action
# [0.24972515 0.25002486 0.25002515 0.25022484]
# Exploring: Taking a random action
# [0.24970018 0.25009985 0.25000015 0.25019982]
# Exploiting: Taking the best-known action
# [0.24977521 0.25007484 0.24997516 0.2501748 ]
# Exploring: Taking a random action
# [0.24977576 0.25017447 0.2499751  0.25007468]
# Exploring: Taking a random action
# [0.24975078 0.25024944 0.2499501  0.25004967]
# Exploiting: Taking the best-known action
# [0.24972581 0.25032441 0.24992511 0.25002467]
# Exploring: Taking a random action
# [0.24985022 0.25004983 0.24995016 0.25014978]
# Exploring: Taking a random action
# ...
# Exploiting: Taking the best-known action
# [0.25010032 0.25029771 0.24940177 0.2502002 ]
# Exploring: Taking a random action
# [0.25002485 0.25002529 0.24992483 0.25002503]
# Exploiting: Taking the best-known action
# [0.24999985 0.25000029 0.24989984 0.25010002]
# Exploring: Taking a random action
# [0.25007489 0.24987507 0.24987508 0.25017495]
# Exploring: Taking a random action
# [0.25004989 0.24995008 0.2498501  0.25014994]
# Exploiting: Taking the best-known action
# [0.25002489 0.24992508 0.24982511 0.25022491]
# Exploring: Taking a random action
# [0.24049589 0.27900249 0.24049468 0.24000694]
# Exploiting: Taking the best-known action
# [0.23811474 0.28614108 0.23811355 0.23763063]
# Episode 30: Reached goal in 17 steps with total reward 0.84
# Exploiting: Taking the best-known action
# [0.25025808 0.2504859  0.24946911 0.24978692]
# Exploring: Taking a random action
# [0.25007531 0.25027268 0.24937683 0.25027517]
# Exploiting: Taking the best-known action
# [0.2501503  0.25024766 0.2493519  0.25025015]
# Exploiting: Taking the best-known action
# [0.25012529 0.25022264 0.24932696 0.25032512]
# Exploring: Taking a random action
# [0.24997485 0.24997529 0.24997484 0.25007501]
# Exploiting: Taking the best-known action
# [0.24994986 0.2499503  0.24994985 0.25015   ]
# Exploiting: Taking the best-known action
# [0.24999989 0.24990009 0.24980013 0.25029988]
# Exploring: Taking a random action
# [0.23809093 0.28621246 0.23808974 0.23760687]
# Exploiting: Taking the best-known action
# [0.23573359 0.29327966 0.23573241 0.23525433]
# Episode 31: Reached goal in 9 steps with total reward 0.92
# Exploiting: Taking the best-known action
# [0.25023305 0.25046085 0.24944416 0.24986193]
# Exploring: Taking a random action
# [0.25010028 0.25029761 0.24930203 0.25030009]
# Exploiting: Taking the best-known action
# [0.25007527 0.25027258 0.24927711 0.25037505]
# Exploiting: Taking the best-known action
# [0.24992487 0.2499253  0.24992486 0.25022497]
# Exploring: Taking a random action
# [0.24997489 0.2499751  0.24977516 0.25027486]
# Exploiting: Taking the best-known action
# [0.24994989 0.2499501  0.24975018 0.25034982]
# Exploring: Taking a random action
# [0.23571002 0.29335033 0.23570884 0.23523081]
# Exploring: Taking a random action
# [0.23568645 0.29332099 0.23568528 0.23530728]
# Exploring: Taking a random action
# [0.23566289 0.29329167 0.2357617  0.23528375]
# Exploring: Taking a random action
# [0.23563932 0.29336233 0.23573813 0.23526022]
# Exploiting: Taking the best-known action
# [0.23330626 0.30035874 0.23340408 0.23293091]
# Episode 32: Reached goal in 11 steps with total reward 0.90
# Exploiting: Taking the best-known action
# [0.25020803 0.25043581 0.24941922 0.24993694]
# Exploiting: Taking the best-known action
# [0.25005026 0.25024755 0.24925218 0.25045   ]
# Exploiting: Taking the best-known action
# [0.24989988 0.24990031 0.24989987 0.25029994]
# Exploiting: Taking the best-known action
# [0.2499249  0.24992511 0.24972521 0.25042478]
# Exploiting: Taking the best-known action
# [0.2309963  0.30728588 0.23109315 0.23062467]
# Episode 33: Reached goal in 5 steps with total reward 0.96
# Exploring: Taking a random action
# [0.25018302 0.25041077 0.24949427 0.24991195]
# Exploiting: Taking the best-known action
# [0.250158   0.25038573 0.24946932 0.24998695]
# Exploiting: Taking the best-known action
# [0.25002526 0.25022253 0.24922726 0.25052495]
# Exploiting: Taking the best-known action
# [0.24987489 0.24987533 0.24987488 0.25037491]
# Exploring: Taking a random action
# [0.24989991 0.25000011 0.24970024 0.25039974]
# Exploring: Taking a random action
# [0.24987492 0.24997511 0.24967527 0.25047469]
# Exploring: Taking a random action
# [0.24994993 0.24995012 0.24965031 0.25044965]
# Exploiting: Taking the best-known action
# [0.24992494 0.24992512 0.24962534 0.2505246 ]
# Exploring: Taking a random action
# [0.2309732  0.30725516 0.23107005 0.2307016 ]
# Exploiting: Taking the best-known action
# [0.22868634 0.31411402 0.22878222 0.22841742]
# Episode 34: Reached goal in 10 steps with total reward 0.91
# Exploring: Taking a random action
# [0.25013299 0.25036069 0.24944438 0.25006194]
# Exploiting: Taking the best-known action
# [0.25010798 0.25033566 0.24941944 0.25013693]
# Exploiting: Taking the best-known action
# [0.25000026 0.25019751 0.24920234 0.25059989]
# Exploiting: Taking the best-known action
# [0.2498499  0.24985034 0.24984989 0.25044986]
# Exploring: Taking a random action
# [0.24999994 0.24990013 0.24960038 0.25049955]
# Exploiting: Taking the best-known action
# [0.24997494 0.24987515 0.24957543 0.25057449]
# Exploiting: Taking the best-known action
# [0.22642212 0.32090497 0.22651705 0.22615586]
# Episode 35: Reached goal in 7 steps with total reward 0.94
# Exploiting: Taking the best-known action
# [0.25008297 0.25031063 0.2493945  0.25021191]
# Exploiting: Taking the best-known action
# [0.24997526 0.25017249 0.24917742 0.25067482]
# Exploiting: Taking the best-known action
# [0.24982492 0.24982536 0.24982491 0.25052481]
# Exploiting: Taking the best-known action
# [0.24994994 0.24985016 0.24955047 0.25064942]
# Exploring: Taking a random action
# [0.22639948 0.32097287 0.2264944  0.22613325]
# Exploiting: Taking the best-known action
# [0.2241579  0.32769591 0.22425188 0.22389431]
# Episode 36: Reached goal in 6 steps with total reward 0.95
# Exploring: Taking a random action
# [0.25015795 0.2502856  0.24936956 0.25018689]
# Exploiting: Taking the best-known action
# [0.25013294 0.25026057 0.24934463 0.25026186]
# Exploiting: Taking the best-known action
# [0.24995027 0.25014748 0.2491525  0.25074975]
# Exploiting: Taking the best-known action
# [0.24979994 0.24980038 0.24979993 0.25059975]
# Exploiting: Taking the best-known action
# [0.24992495 0.24982518 0.24952552 0.25072435]
# Exploring: Taking a random action
# [0.22413548 0.32776314 0.22422946 0.22387192]
# Exploring: Taking a random action
# [0.22411307 0.32773036 0.22430703 0.22384953]
# Exploiting: Taking the best-known action
# [0.22189413 0.3343865  0.22208617 0.2216332 ]
# Episode 37: Reached goal in 8 steps with total reward 0.93
# Exploring: Taking a random action
# [0.25010793 0.25033554 0.24931969 0.25023684]
# Exploring: Taking a random action
# [0.25008292 0.2504105  0.24929476 0.25021182]
# Exploiting: Taking the best-known action
# [0.25005791 0.25038546 0.24926984 0.25028679]
# Exploring: Taking a random action
# [0.24992528 0.25022246 0.24912759 0.25072468]
# Exploring: Taking a random action
# [0.24990029 0.25029743 0.24910268 0.25069961]
# Exploiting: Taking the best-known action
# [0.2498753  0.2502724  0.24907777 0.25077453]
# Exploiting: Taking the best-known action
# [0.24977496 0.2497754  0.24977495 0.25067468]
# Exploiting: Taking the best-known action
# [0.24989996 0.2498002  0.24950057 0.25079927]
# Exploring: Taking a random action
# [0.22197193 0.33435306 0.22206396 0.22161104]
# Exploring: Taking a random action
# [0.22204973 0.33431963 0.22204176 0.22158888]
# Exploring: Taking a random action
# [0.22202753 0.3342862  0.22201956 0.22166672]
# Exploiting: Taking the best-known action
# [0.21982923 0.34087743 0.21982134 0.219472  ]
# Episode 38: Reached goal in 12 steps with total reward 0.89
# Exploiting: Taking the best-known action
# [0.25003291 0.25036042 0.24924491 0.25036175]
# Exploiting: Taking the best-known action
# [0.24985031 0.25024738 0.24905287 0.25084944]
# Exploiting: Taking the best-known action
# [0.24974999 0.24975043 0.24974998 0.25074961]
# Exploiting: Taking the best-known action
# [0.24987497 0.24977522 0.24947562 0.25087418]
# Exploiting: Taking the best-known action
# [0.21765271 0.34740339 0.21764489 0.21729901]
# Episode 39: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.25000791 0.25033539 0.24921999 0.25043671]
# Exploiting: Taking the best-known action
# [0.24982533 0.25022235 0.24902797 0.25092435]
# Exploiting: Taking the best-known action
# [0.24972502 0.24972545 0.24972501 0.25082452]
# Exploiting: Taking the best-known action
# [0.24984999 0.24975025 0.24945068 0.25094909]
# Exploiting: Taking the best-known action
# [0.21549773 0.35386475 0.21548999 0.21514753]
# Episode 40: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.24998291 0.25031036 0.24919507 0.25051166]
# Exploring: Taking a random action
# [0.24980035 0.25019733 0.24900306 0.25099925]
# Exploring: Taking a random action
# [0.24977537 0.25017232 0.24907816 0.25097415]
# Exploiting: Taking the best-known action
# [0.2497504  0.2501473  0.24905325 0.25104905]
# Exploiting: Taking the best-known action
# [0.24970005 0.24970048 0.24970004 0.25089943]
# Exploring: Taking a random action
# [0.24982501 0.24972527 0.24952572 0.250924  ]
# Exploiting: Taking the best-known action
# [0.24980003 0.2497003  0.24950077 0.2509989 ]
# Exploiting: Taking the best-known action
# [0.21336409 0.36026212 0.21335643 0.21301736]
# Episode 41: Reached goal in 8 steps with total reward 0.93
# Exploiting: Taking the best-known action
# [0.24995791 0.25028533 0.24917015 0.2505866 ]
# Exploiting: Taking the best-known action
# [0.24972543 0.25012229 0.24902835 0.25112394]
# Exploiting: Taking the best-known action
# [0.24967508 0.24967552 0.24967507 0.25097434]
# Exploiting: Taking the best-known action
# [0.24977505 0.24967534 0.24947583 0.25107379]
# Exploiting: Taking the best-known action
# [0.21125157 0.36659616 0.21124399 0.21090827]
# Episode 42: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.24993292 0.25026031 0.24914524 0.25066153]
# Exploiting: Taking the best-known action
# [0.24970046 0.25009728 0.24900345 0.25119882]
# Exploiting: Taking the best-known action
# [0.24965011 0.24965055 0.2496501  0.25104923]
# Exploiting: Taking the best-known action
# [0.24975007 0.24965037 0.24945088 0.25114867]
# Exploiting: Taking the best-known action
# [0.20915997 0.37286749 0.20915247 0.20882007]
# Episode 43: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.24990793 0.25023528 0.24912033 0.25073646]
# Exploiting: Taking the best-known action
# [0.24967549 0.25007227 0.24897855 0.25127369]
# Exploring: Taking a random action
# [0.24972514 0.24962559 0.24962514 0.25102413]
# Exploiting: Taking the best-known action
# [0.24970017 0.24960063 0.24960018 0.25109902]
# Exploiting: Taking the best-known action
# [0.2497251  0.24962541 0.24942594 0.25122355]
# Exploiting: Taking the best-known action
# [0.20708908 0.37907672 0.20708165 0.20675255]
# Episode 44: Reached goal in 6 steps with total reward 0.95
# Exploiting: Taking the best-known action
# [0.24988294 0.25021026 0.24909542 0.25081138]
# Exploiting: Taking the best-known action
# [0.24965052 0.25004727 0.24895366 0.25134855]
# Exploiting: Taking the best-known action
# [0.2496752  0.24957567 0.24957522 0.2511739 ]
# Exploiting: Taking the best-known action
# [0.24970013 0.24960045 0.249401   0.25129842]
# Exploiting: Taking the best-known action
# [0.20503869 0.38522448 0.20503134 0.20470549]
# Episode 45: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.24985796 0.25018524 0.24907051 0.25088629]
# Exploiting: Taking the best-known action
# [0.24962556 0.25002227 0.24892876 0.25142341]
# Exploiting: Taking the best-known action
# [0.24965024 0.24955072 0.24955027 0.25124878]
# Exploiting: Taking the best-known action
# [0.24967516 0.24957549 0.24937606 0.25137328]
# Exploiting: Taking the best-known action
# [0.20300861 0.39131136 0.20300132 0.20267871]
# Episode 46: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.24983297 0.25016023 0.24904561 0.25096119]
# Exploiting: Taking the best-known action
# [0.2496006  0.24999727 0.24890387 0.25149826]
# Exploring: Taking a random action
# [0.24962528 0.24952576 0.24952532 0.25132365]
# Exploiting: Taking the best-known action
# [0.24960032 0.24950081 0.24950037 0.25139851]
# Exploring: Taking a random action
# [0.2496502  0.24965053 0.24935113 0.25134815]
# Exploiting: Taking the best-known action
# [0.24962524 0.24962556 0.24932619 0.25142301]
# Exploiting: Taking the best-known action
# [0.20099862 0.39733798 0.20099141 0.20067199]
# Episode 47: Reached goal in 7 steps with total reward 0.94
# Exploiting: Taking the best-known action
# [0.24980799 0.25013521 0.2490207  0.25103609]
# Exploiting: Taking the best-known action
# [0.24957564 0.24997227 0.24887898 0.2515731 ]
# Exploiting: Taking the best-known action
# [0.24957536 0.24947587 0.24947542 0.25147336]
# Exploiting: Taking the best-known action
# [0.24960028 0.2496006  0.24930126 0.25149786]
# Exploiting: Taking the best-known action
# [0.19900854 0.40330493 0.19900139 0.19868514]
# Episode 48: Reached goal in 5 steps with total reward 0.96
# Exploiting: Taking the best-known action
# [0.24978301 0.2501102  0.2489958  0.25111098]
# Exploring: Taking a random action
# [0.24955069 0.25004726 0.2488541  0.25154795]
# Exploiting: Taking the best-known action
# [0.24952573 0.25002226 0.24882922 0.25162279]
# Exploiting: Taking the best-known action
# [0.2495504  0.24945092 0.24945047 0.2515482 ]
# Exploiting: Taking the best-known action
# [0.24957532 0.24957565 0.24927634 0.2515727 ]
# Exploiting: Taking the best-known action
# [0.19703816 0.40921281 0.19703108 0.19671796]
# Episode 49: Reached goal in 6 steps with total reward 0.95
# Exploiting: Taking the best-known action
# [0.24975804 0.25008519 0.24897091 0.25118586]
# Exploiting: Taking the best-known action
# [0.24950078 0.24999726 0.24880434 0.25169762]
# Exploiting: Taking the best-known action
# [0.24952545 0.24942598 0.24942553 0.25162304]
# Exploiting: Taking the best-known action
# [0.24955036 0.24955069 0.24925141 0.25164754]
# Exploiting: Taking the best-known action
# [0.19508728 0.41506218 0.19508028 0.19477025]
# Episode 50: Reached goal in 5 steps with total reward 0.96
# Final Q-table:
# [[[-0.03557502 -0.03417248 -0.03668251  0.03522072]
#   [-0.01306662 -0.00272816 -0.01061555  0.14477559]
#   [ 0.00822389 -0.00966179 -0.00914388  0.34785761]
#   [ 0.02566225  0.06528551  0.02946306  0.63686828]
#   [ 0.17483367  0.92248529  0.1474897   0.14898384]]
#
#  [[-0.03205028 -0.03174097 -0.03156475 -0.03404935]
#   [-0.03687171 -0.01091874 -0.02227186 -0.019     ]
#   [-0.00837919 -0.00795696 -0.0117369  -0.00821284]
#   [-0.00484507 -0.01172037 -0.00505818  0.0958041 ]
#   [ 0.          0.          0.          0.        ]]
#
#  [[-0.03149551 -0.02830913 -0.03016047 -0.03262762]
#   [-0.01144933 -0.00740912 -0.00931798 -0.00757955]
#   [-0.0066876  -0.01134339 -0.00595302 -0.01277959]
#   [-0.0019     -0.01       -0.00132336  0.        ]
#   [ 0.          0.          0.          0.        ]]
#
#  [[-0.02058095 -0.0212822  -0.02063008 -0.01996698]
#   [-0.01175957 -0.01136996 -0.01367207 -0.01232615]
#   [-0.001      -0.02680339 -0.00176999  0.        ]
#   [-0.01        0.          0.          0.        ]
#   [-0.001      -0.001      -0.00199    -0.00199   ]]
#
#  [[-0.01896334 -0.02191895 -0.01856398 -0.01883297]
#   [-0.01548176 -0.01609431 -0.01570218 -0.01547636]
#   [-0.01477202 -0.01192328 -0.01290804 -0.01220184]
#   [-0.0101791  -0.00585199 -0.00666307 -0.00582477]
#   [-0.0019     -0.00199    -0.001      -0.001     ]]]
# Final Policy Probabilities:
# [[[0.24975804 0.25008519 0.24897091 0.25118586]
#   [0.24950078 0.24999726 0.24880434 0.25169762]
#   [0.24952545 0.24942598 0.24942553 0.25162304]
#   [0.24955036 0.24955069 0.24925141 0.25164754]
#   [0.19508728 0.41506218 0.19508028 0.19477025]]
#
#  [[0.24920538 0.25000472 0.24989933 0.25089057]
#   [0.25162101 0.24893142 0.24982712 0.24962045]
#   [0.24990054 0.24980078 0.25039782 0.24990086]
#   [0.24735201 0.24824101 0.24725316 0.25715381]
#   [0.25       0.25       0.25       0.25      ]]
#
#  [[0.24923237 0.25092245 0.24893332 0.25091186]
#   [0.25044765 0.24975091 0.24985053 0.2499509 ]
#   [0.24975112 0.25024843 0.24955116 0.25044929]
#   [0.24987509 0.25067424 0.24977533 0.24967534]
#   [0.25       0.25       0.25       0.25      ]]
#
#  [[0.24927836 0.25087113 0.24977555 0.25007495]
#   [0.25017558 0.24957611 0.24997582 0.2502725 ]
#   [0.24927661 0.25226993 0.24927673 0.24917674]
#   [0.25074925 0.24975025 0.24975025 0.24975025]
#   [0.24995    0.24995001 0.25004998 0.25005   ]]
#
#  [[0.24940285 0.25029935 0.24970024 0.25059756]
#   [0.25044909 0.25004923 0.24955125 0.24995043]
#   [0.2507205  0.24972572 0.2496273  0.24992648]
#   [0.25042305 0.2498256  0.24982572 0.24992563]
#   [0.25005    0.25004997 0.24995    0.24995002]]]

# %%
# Environment setup
goal_position = (4, 4)
reward_goal = 1
reward_step = -0.01  # Small penalty to encourage shorter paths
reward_slip = -0.1   # Penalty for slipping

# Run multiple episodes to test learning
num_episodes = 50
for episode in range(num_episodes):
    state = (0, 0)  # Starting position
    total_reward = 0
    epsilon = max(0.1, 1 - episode / num_episodes)  # Decrease epsilon over time

    for step in range(10):  # Max steps per episode
        # Choose action (explore/exploit based on Q-learning)
        action = choose_action(state, epsilon)
        
        # Apply slippery effect if the cell is slippery
        if state in slippery_cells:
            action = apply_slippery(action)
        
        # Move agent based on action (0: up, 1: down, 2: left, 3: right)
        next_state = (state[0] + (action == 1) - (action == 0), 
                      state[1] + (action == 3) - (action == 2))

        # Check if next_state is within bounds
        if not (0 <= next_state[0] < grid_size and 0 <= next_state[1] < grid_size):
            next_state = state  # Stay in place if out of bounds
            reward = reward_step  # Penalty for attempting invalid move
        elif next_state == goal_position:
            reward = reward_goal  # Reward for reaching the goal
        elif next_state in slippery_cells:
            reward = reward_slip  # Penalty for landing on a slippery cell
        else:
            reward = reward_step  # Default step penalty

        # Update Q-table (Q-learning update)
        old_q_value = q_table[state][action]
        next_best_q = np.max(q_table[next_state])
        q_table[state][action] = old_q_value + 0.1 * (reward + 0.9 * next_best_q - old_q_value)

        # Update Policy using Policy Gradient (if goal reached)
        policy_gradient_step(state, action, reward)
        
        # Move to the next state
        state = next_state
        total_reward += reward

        # End the episode if the goal is reached
        if state == goal_position:
            print(f"Episode {episode + 1}: Reached goal in {step + 1} steps with total reward {total_reward:.2f}")
            break
    else:
        print(f"Episode {episode + 1}: Did not reach the goal. Total reward: {total_reward:.2f}")

# Print final Q-table and policy probabilities for inspection
print("Final Q-table:")
print(q_table)
print("Final Policy Probabilities:")
print(policy)
# Out:
# Exploring: Taking a random action
# [0.24969836 0.24599188 0.24953119 0.25477857]
# Exploring: Taking a random action
# [0.24977338 0.24596728 0.24950624 0.25475309]
# Exploring: Taking a random action
# [0.24974841 0.24594269 0.24948129 0.25482761]
# Exploring: Taking a random action
# [0.24972343 0.2459181  0.24945635 0.25490212]
# Exploring: Taking a random action
# [0.24969846 0.24589351 0.24943141 0.25497662]
# Exploring: Taking a random action
# [0.2496735  0.24586892 0.24940647 0.25505112]
# Exploring: Taking a random action
# [0.24964853 0.24594432 0.24938153 0.25502562]
# Exploring: Taking a random action
# [0.24962357 0.24591973 0.24945658 0.25500012]
# Exploring: Taking a random action
# [0.24959861 0.24599513 0.24943164 0.25497462]
# Exploring: Taking a random action
# [0.24967364 0.24597054 0.2494067  0.25494912]
# Episode 1: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24964868 0.24594594 0.24948175 0.25492363]
# Exploring: Taking a random action
# [0.24962372 0.24602134 0.2494568  0.25489814]
# Exploring: Taking a random action
# [0.24969875 0.24599674 0.24943186 0.25487265]
# Exploring: Taking a random action
# [0.24967378 0.24607213 0.24940692 0.25484717]
# Exploring: Taking a random action
# [0.24964881 0.24604753 0.24948197 0.25482169]
# Exploring: Taking a random action
# [0.24962385 0.24602293 0.24945703 0.2548962 ]
# Exploring: Taking a random action
# [0.24959889 0.24599833 0.24953207 0.25487071]
# Exploring: Taking a random action
# [0.24957393 0.24597373 0.24950712 0.25494522]
# Exploring: Taking a random action
# [0.24954898 0.24594913 0.24958216 0.25491972]
# Exploring: Taking a random action
# [0.24952403 0.24592454 0.24955721 0.25499422]
# Episode 2: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24949908 0.24589995 0.24953225 0.25506872]
# Exploring: Taking a random action
# [0.24947413 0.24587536 0.2495073  0.2551432 ]
# Exploring: Taking a random action
# [0.24944918 0.24585078 0.24958235 0.25511769]
# Exploring: Taking a random action
# [0.24942424 0.24592619 0.24955739 0.25509218]
# Exploring: Taking a random action
# [0.2493993  0.2459016  0.24963243 0.25506668]
# Exploring: Taking a random action
# [0.24937436 0.245977   0.24960747 0.25504117]
# Exploring: Taking a random action
# [0.24934943 0.2459524  0.24958251 0.25511566]
# Exploring: Taking a random action
# [0.24942449 0.24592781 0.24955755 0.25509015]
# Exploring: Taking a random action
# [0.24949954 0.24590322 0.2495326  0.25506464]
# Exploring: Taking a random action
# [0.24947459 0.24587863 0.24950765 0.25513913]
# Episode 3: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24944964 0.24595404 0.2494827  0.25511362]
# Exploring: Taking a random action
# [0.2494247  0.24592944 0.24955774 0.25508811]
# Exploring: Taking a random action
# [0.24939976 0.24600484 0.24953279 0.2550626 ]
# Exploring: Taking a random action
# [0.24937482 0.24598024 0.24960783 0.2550371 ]
# Exploring: Taking a random action
# [0.24944988 0.24595565 0.24958287 0.2550116 ]
# Exploring: Taking a random action
# [0.24942494 0.24593106 0.24965791 0.2549861 ]
# Exploring: Taking a random action
# [0.2494     0.24590647 0.24973293 0.2549606 ]
# Exploring: Taking a random action
# [0.24937506 0.24588188 0.24970796 0.2550351 ]
# Exploring: Taking a random action
# [0.24945011 0.24585729 0.24968299 0.2550096 ]
# Exploring: Taking a random action
# [0.24952516 0.24583271 0.24965803 0.2549841 ]
# Episode 4: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24950021 0.24580813 0.24963306 0.2550586 ]
# Exploring: Taking a random action
# [0.24947526 0.24578355 0.24970809 0.25503309]
# Exploring: Taking a random action
# [0.24945032 0.24575897 0.24978312 0.25500759]
# Exploring: Taking a random action
# [0.24942538 0.24583439 0.24975814 0.25498209]
# Exploring: Taking a random action
# [0.24950043 0.24580981 0.24973317 0.2549566 ]
# Exploring: Taking a random action
# [0.24957547 0.24578523 0.2497082  0.25493111]
# Exploring: Taking a random action
# [0.2496505  0.24576065 0.24968323 0.25490561]
# Exploring: Taking a random action
# [0.24962554 0.24573608 0.24975825 0.25488013]
# Exploring: Taking a random action
# [0.24960058 0.24571151 0.24983327 0.25485464]
# Exploring: Taking a random action
# [0.24967561 0.24568694 0.24980829 0.25482916]
# Episode 5: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24965065 0.24576236 0.24978331 0.25480368]
# Exploiting: Taking the best-known action
# [0.25023169 0.24962997 0.24962489 0.25051345]
# Exploring: Taking a random action
# [0.24962569 0.24573779 0.24985832 0.2547782 ]
# Exploring: Taking a random action
# [0.24960073 0.24571322 0.24983334 0.25485271]
# Exploiting: Taking the best-known action
# [0.24957577 0.24578864 0.24980836 0.25482723]
# Exploring: Taking a random action
# [0.25020667 0.24960501 0.24969992 0.2504884 ]
# Exploiting: Taking the best-known action
# [0.25028164 0.24958005 0.24967496 0.25046335]
# Exploring: Taking a random action
# [0.24955081 0.24586405 0.24978338 0.25480175]
# Exploring: Taking a random action
# [0.24962585 0.24583947 0.2497584  0.25477627]
# Exploring: Taking a random action
# [0.24960089 0.24591488 0.24973343 0.2547508 ]
# Episode 6: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24967592 0.24589029 0.24970846 0.25472533]
# Exploring: Taking a random action
# [0.24975095 0.2458657  0.24968349 0.25469986]
# Exploring: Taking a random action
# [0.24972598 0.24584112 0.24965853 0.25477438]
# Exploring: Taking a random action
# [0.24970101 0.24581654 0.24963356 0.25484889]
# Exploring: Taking a random action
# [0.24967604 0.24589195 0.2496086  0.25482341]
# Exploring: Taking a random action
# [0.24965107 0.24596735 0.24958364 0.25479793]
# Exploring: Taking a random action
# [0.24962611 0.24594276 0.24965868 0.25477245]
# Exploring: Taking a random action
# [0.24960115 0.24591817 0.2497337  0.25474698]
# Exploring: Taking a random action
# [0.24967618 0.24589358 0.24970873 0.25472151]
# Exploring: Taking a random action
# [0.24975121 0.24586899 0.24968377 0.25469604]
# Episode 7: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24972623 0.2458444  0.24975879 0.25467057]
# Exploiting: Taking the best-known action
# [0.24970126 0.24581982 0.24973382 0.2547451 ]
# Exploring: Taking a random action
# [0.2485707  0.24992627 0.24628654 0.2552165 ]
# Exploiting: Taking the best-known action
# [0.24854584 0.24990128 0.24626191 0.25529097]
# Exploring: Taking a random action
# [0.25053504 0.24574305 0.24970983 0.25401207]
# Exploring: Taking a random action
# [0.25060998 0.24571848 0.24968487 0.25398668]
# Exploring: Taking a random action
# [0.25068491 0.24569391 0.2496599  0.25396128]
# Exploring: Taking a random action
# [0.25065985 0.24576933 0.24963494 0.25393589]
# Exploring: Taking a random action
# [0.25073477 0.24574476 0.24960998 0.2539105 ]
# Exploring: Taking a random action
# [0.2507097  0.24572019 0.24968501 0.25388511]
# Episode 8: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.2496763  0.24579524 0.24970884 0.25481961]
# Exploiting: Taking the best-known action
# [0.24862098 0.24987629 0.24623729 0.25526544]
# Exploiting: Taking the best-known action
# [0.24859612 0.24985131 0.24631265 0.25523992]
# Exploring: Taking a random action
# [0.24965133 0.24577067 0.24978387 0.25479414]
# Exploring: Taking a random action
# [0.24962637 0.24574609 0.24975889 0.25486865]
# Exploring: Taking a random action
# [0.24960141 0.24582151 0.24973392 0.25484316]
# Exploring: Taking a random action
# [0.24957645 0.24579693 0.24970895 0.25491767]
# Exploring: Taking a random action
# [0.2495515  0.24577235 0.24978397 0.25489218]
# Exploring: Taking a random action
# [0.24952654 0.24584777 0.24975899 0.2548667 ]
# Exploring: Taking a random action
# [0.24950159 0.24592318 0.24973402 0.25484121]
# Episode 9: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24957664 0.24589859 0.24970905 0.25481573]
# Exploring: Taking a random action
# [0.24955168 0.24597399 0.24968408 0.25479025]
# Exploring: Taking a random action
# [0.24952673 0.24594939 0.24965911 0.25486477]
# Exploring: Taking a random action
# [0.24950178 0.2459248  0.24973414 0.25483928]
# Exploring: Taking a random action
# [0.24957682 0.24590021 0.24970917 0.2548138 ]
# Exploring: Taking a random action
# [0.24955186 0.24587562 0.24978419 0.25478832]
# Exploring: Taking a random action
# [0.24952691 0.24585104 0.24975921 0.25486284]
# Exploring: Taking a random action
# [0.24950196 0.24582646 0.24973424 0.25493734]
# Exploring: Taking a random action
# [0.249577   0.24580188 0.24970927 0.25491185]
# Exploring: Taking a random action
# [0.24955205 0.24587729 0.2496843  0.25488636]
# Episode 10: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.2495271  0.2458527  0.24965934 0.25496087]
# Exploring: Taking a random action
# [0.24950215 0.24582812 0.24973436 0.25493537]
# Exploiting: Taking the best-known action
# [0.2494772  0.24580354 0.24970939 0.25500987]
# Exploring: Taking a random action
# [0.24857126 0.24982633 0.24638802 0.2552144 ]
# Exploiting: Taking the best-known action
# [0.24854641 0.24980135 0.24636338 0.25528887]
# Exploring: Taking a random action
# [0.25068463 0.24569562 0.24976003 0.25385972]
# Exploring: Taking a random action
# [0.25065957 0.24577104 0.24973506 0.25383434]
# Exploring: Taking a random action
# [0.2506345  0.24584645 0.24971009 0.25380896]
# Exploring: Taking a random action
# [0.25070943 0.24582187 0.24968512 0.25378358]
# Exploring: Taking a random action
# [0.25078435 0.24579729 0.24966015 0.2537582 ]
# Episode 11: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24945225 0.24577896 0.24968442 0.25508436]
# Exploring: Taking a random action
# [0.24852156 0.24977637 0.24643874 0.25526334]
# Exploring: Taking a random action
# [0.24849671 0.24975139 0.24651408 0.25523782]
# Exploiting: Taking the best-known action
# [0.24857185 0.24972642 0.24648944 0.2552123 ]
# Exploiting: Taking the best-known action
# [0.24854699 0.24970145 0.24646479 0.25528677]
# Exploring: Taking a random action
# [0.25085927 0.24577271 0.24963519 0.25373283]
# Exploring: Taking a random action
# [0.25083418 0.24584813 0.24961023 0.25370746]
# Exploring: Taking a random action
# [0.25090909 0.24582355 0.24958527 0.25368209]
# Exploring: Taking a random action
# [0.25088401 0.24579897 0.24956031 0.25375671]
# Exploring: Taking a random action
# [0.25095891 0.24577439 0.24953536 0.25373134]
# Episode 12: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.2495273  0.24575439 0.24965946 0.25505886]
# Exploiting: Taking the best-known action
# [0.24950235 0.24572981 0.24963449 0.25513334]
# Exploiting: Taking the best-known action
# [0.24852214 0.24967648 0.24644014 0.25536123]
# Exploring: Taking a random action
# [0.25103381 0.24574982 0.24951041 0.25370597]
# Exploring: Taking a random action
# [0.2511087  0.24572524 0.24948546 0.2536806 ]
# Exploring: Taking a random action
# [0.25108359 0.24580066 0.24946051 0.25365524]
# Exploiting: Taking the best-known action
# [0.25105848 0.24577608 0.24943557 0.25372986]
# Exploring: Taking a random action
# [0.24839216 0.24787666 0.24843691 0.25529427]
# Exploring: Taking a random action
# [0.24836732 0.24785187 0.24841207 0.25536873]
# Exploring: Taking a random action
# [0.24834249 0.24782709 0.24838723 0.25544319]
# Episode 13: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.2494774  0.24570524 0.24960953 0.25520782]
# Exploring: Taking a random action
# [0.24849729 0.24965152 0.24651549 0.2553357 ]
# Exploring: Taking a random action
# [0.24847244 0.24962656 0.24659083 0.25531017]
# Exploring: Taking a random action
# [0.2484476  0.24970158 0.24656618 0.25528464]
# Exploring: Taking a random action
# [0.24842276 0.24967662 0.24664151 0.25525911]
# Exploring: Taking a random action
# [0.24849791 0.24965165 0.24661685 0.25523359]
# Exploring: Taking a random action
# [0.24847306 0.24972668 0.24659219 0.25520807]
# Exploring: Taking a random action
# [0.24844822 0.24970171 0.24656754 0.25528254]
# Exploring: Taking a random action
# [0.24852336 0.24967674 0.24654288 0.25525701]
# Exploring: Taking a random action
# [0.24849851 0.24975177 0.24651823 0.25523149]
# Episode 14: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24945246 0.24578066 0.24958457 0.2551823 ]
# Exploring: Taking a random action
# [0.24942751 0.24575609 0.24955962 0.25525678]
# Exploiting: Taking the best-known action
# [0.24940257 0.24573152 0.24953466 0.25533125]
# Exploiting: Taking the best-known action
# [0.24847367 0.24972679 0.24649358 0.25530596]
# Exploiting: Taking the best-known action
# [0.25103338 0.24575151 0.24941063 0.25380448]
# Exploring: Taking a random action
# [0.24831765 0.24780231 0.24846239 0.25541765]
# Exploiting: Taking the best-known action
# [0.24829283 0.24787752 0.24843754 0.25539211]
# Exploring: Taking a random action
# [0.25040996 0.25028422 0.24469395 0.25461188]
# Exploiting: Taking the best-known action
# [0.25048491 0.25025919 0.24466948 0.25458642]
# Exploiting: Taking the best-known action
# [0.24836799 0.24785274 0.2484127  0.25536657]
# Episode 15: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24937764 0.24570694 0.2496097  0.25530571]
# Exploiting: Taking the best-known action
# [0.2493527  0.24568238 0.24958475 0.25538018]
# Exploring: Taking a random action
# [0.24844882 0.24980181 0.24646893 0.25528043]
# Exploiting: Taking the best-known action
# [0.24852397 0.24977684 0.24644429 0.25525491]
# Exploiting: Taking the best-known action
# [0.24849912 0.24975186 0.24641965 0.25532937]
# Exploring: Taking a random action
# [0.25100828 0.24572694 0.24938569 0.2538791 ]
# Exploiting: Taking the best-known action
# [0.25098318 0.24570237 0.24946074 0.25385371]
# Exploring: Taking a random action
# [0.24847427 0.24972689 0.246495   0.25530384]
# Exploiting: Taking the best-known action
# [0.24844943 0.24970192 0.24647035 0.2553783 ]
# Exploiting: Taking the best-known action
# [0.25095808 0.2456778  0.2494358  0.25392832]
# Episode 16: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24932777 0.24565781 0.24955979 0.25545463]
# Exploiting: Taking the best-known action
# [0.24930284 0.24563325 0.24953484 0.25552908]
# Exploring: Taking a random action
# [0.24842458 0.24967695 0.24644571 0.25545276]
# Exploring: Taking a random action
# [0.24839974 0.24975197 0.24642106 0.25542722]
# Exploiting: Taking the best-known action
# [0.2484749  0.249727   0.24639642 0.25540168]
# Exploiting: Taking the best-known action
# [0.24855004 0.24970203 0.24637179 0.25537614]
# Exploring: Taking a random action
# [0.24862518 0.24967706 0.24634715 0.2553506 ]
# Exploring: Taking a random action
# [0.24860032 0.2496521  0.24642251 0.25532507]
# Exploring: Taking a random action
# [0.24857546 0.24972713 0.24639787 0.25529954]
# Exploiting: Taking the best-known action
# [0.24855061 0.24970216 0.24637323 0.255374  ]
# Episode 17: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.2493779  0.24560869 0.24950989 0.25550353]
# Exploiting: Taking the best-known action
# [0.24935297 0.24558413 0.24948494 0.25557797]
# Exploring: Taking a random action
# [0.24862574 0.24967719 0.2463486  0.25534847]
# Exploiting: Taking the best-known action
# [0.24860088 0.24965222 0.24632397 0.25542293]
# Exploring: Taking a random action
# [0.25103298 0.24565323 0.24941086 0.25390293]
# Exploiting: Taking the best-known action
# [0.25100788 0.24562867 0.24938592 0.25397753]
# Exploring: Taking a random action
# [0.24834315 0.24782795 0.24838786 0.25544103]
# Exploring: Taking a random action
# [0.24841831 0.24780317 0.24836303 0.25541549]
# Exploring: Taking a random action
# [0.24839347 0.2477784  0.24833819 0.25548994]
# Exploiting: Taking the best-known action
# [0.24836864 0.24785361 0.24831336 0.25546439]
# Episode 18: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24932803 0.24565956 0.24945999 0.25555242]
# Exploring: Taking a random action
# [0.2493031  0.24573499 0.24943505 0.25552686]
# Exploring: Taking a random action
# [0.24927817 0.24581041 0.24941011 0.25550131]
# Exploiting: Taking the best-known action
# [0.24925325 0.24578583 0.24938517 0.25557575]
# Exploiting: Taking the best-known action
# [0.24857603 0.24962726 0.24629934 0.25549738]
# Exploiting: Taking the best-known action
# [0.25098278 0.24560411 0.24946097 0.25395213]
# Exploring: Taking a random action
# [0.24865116 0.2496023  0.24627471 0.25547183]
# Exploiting: Taking the best-known action
# [0.2486263  0.24957734 0.24625008 0.25554628]
# Exploring: Taking a random action
# [0.25095768 0.24567954 0.24943603 0.25392674]
# Exploring: Taking a random action
# [0.25093259 0.24565498 0.24951108 0.25390135]
# Episode 19: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24922833 0.24576125 0.24936023 0.25565019]
# Exploring: Taking a random action
# [0.24920341 0.24573668 0.24943529 0.25562463]
# Exploring: Taking a random action
# [0.24917849 0.24571211 0.24941035 0.25569906]
# Exploiting: Taking the best-known action
# [0.24915357 0.24568754 0.24938541 0.25577348]
# Exploiting: Taking the best-known action
# [0.24860144 0.24955239 0.24622546 0.25562071]
# Exploring: Taking a random action
# [0.2509075  0.2457304  0.24948613 0.25387596]
# Exploiting: Taking the best-known action
# [0.25088241 0.24570583 0.24946119 0.25395057]
# Exploiting: Taking the best-known action
# [0.2483438  0.24792882 0.24828853 0.25543885]
# Exploring: Taking a random action
# [0.25055985 0.25023417 0.24464502 0.25456096]
# Exploring: Taking a random action
# [0.25063479 0.25020915 0.24462055 0.25453551]
# Episode 20: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24912866 0.24566297 0.24936047 0.2558479 ]
# Exploiting: Taking the best-known action
# [0.24857658 0.24952743 0.24630083 0.25559515]
# Exploiting: Taking the best-known action
# [0.24910375 0.24563841 0.24933554 0.2559223 ]
# Exploring: Taking a random action
# [0.24855173 0.24960247 0.2462762  0.2555696 ]
# Exploring: Taking a random action
# [0.24852687 0.24957752 0.24625158 0.25564403]
# Exploiting: Taking the best-known action
# [0.24850202 0.24955256 0.24622696 0.25571846]
# Exploring: Taking a random action
# [0.25095732 0.24568127 0.24943624 0.25392518]
# Exploiting: Taking the best-known action
# [0.25093222 0.2456567  0.2494113  0.25399978]
# Exploiting: Taking the best-known action
# [0.24841896 0.24790403 0.24826371 0.25541331]
# Exploiting: Taking the best-known action
# [0.24839412 0.24797923 0.24823888 0.25538777]
# Episode 21: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24907884 0.24561385 0.24931061 0.2559967 ]
# Exploring: Taking a random action
# [0.24857716 0.24952761 0.24620234 0.25569289]
# Exploring: Taking a random action
# [0.24855231 0.24950266 0.24617772 0.25576731]
# Exploiting: Taking the best-known action
# [0.24852746 0.24947771 0.24625309 0.25574174]
# Exploring: Taking a random action
# [0.24905394 0.24568928 0.24928568 0.25597111]
# Exploring: Taking a random action
# [0.24902903 0.24566471 0.24936074 0.25594551]
# Exploring: Taking a random action
# [0.24900413 0.24574014 0.24933581 0.25591992]
# Exploring: Taking a random action
# [0.24907922 0.24571557 0.24931088 0.25589433]
# Exploiting: Taking the best-known action
# [0.24905432 0.245691   0.24928595 0.25596873]
# Exploiting: Taking the best-known action
# [0.2486026  0.24945277 0.24622847 0.25571617]
# Episode 22: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24902942 0.24566643 0.24926102 0.25604313]
# Exploiting: Taking the best-known action
# [0.24857774 0.24942782 0.24620385 0.25579059]
# Exploiting: Taking the best-known action
# [0.25090713 0.24563214 0.24938636 0.25407437]
# Exploring: Taking a random action
# [0.24836928 0.24805442 0.24821406 0.25536223]
# Exploring: Taking a random action
# [0.24844444 0.24802962 0.24818924 0.2553367 ]
# Exploring: Taking a random action
# [0.2484196  0.24800482 0.24826442 0.25531117]
# Exploring: Taking a random action
# [0.24839476 0.24798002 0.24823959 0.25538563]
# Exploiting: Taking the best-known action
# [0.24836992 0.24795523 0.24831476 0.25536009]
# Exploring: Taking a random action
# [0.25088204 0.24570757 0.24936143 0.25404896]
# Exploiting: Taking the best-known action
# [0.25085696 0.245683   0.24933649 0.25412355]
# Episode 23: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24900452 0.24564187 0.2492361  0.25611752]
# Exploiting: Taking the best-known action
# [0.24855288 0.24940288 0.24617923 0.255865  ]
# Exploring: Taking a random action
# [0.25093187 0.24565843 0.24931156 0.25409814]
# Exploring: Taking a random action
# [0.25090677 0.24573386 0.24928663 0.25407273]
# Exploiting: Taking the best-known action
# [0.25088169 0.24570929 0.2493617  0.25404733]
# Exploring: Taking a random action
# [0.24862802 0.24937794 0.24615462 0.25583942]
# Exploiting: Taking the best-known action
# [0.24860316 0.24935301 0.24613    0.25591383]
# Exploiting: Taking the best-known action
# [0.2508566  0.24568472 0.24933676 0.25412192]
# Exploring: Taking a random action
# [0.24844508 0.24793043 0.24828993 0.25533456]
# Exploring: Taking a random action
# [0.24852022 0.24790564 0.24826511 0.25530903]
# Episode 24: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24897962 0.2456173  0.24931117 0.25609191]
# Exploiting: Taking the best-known action
# [0.24895472 0.24559275 0.24928624 0.25616629]
# Exploiting: Taking the best-known action
# [0.2485783  0.24932808 0.24610539 0.25598823]
# Exploiting: Taking the best-known action
# [0.25083152 0.24566015 0.24931183 0.2541965 ]
# Exploring: Taking a random action
# [0.24849537 0.24788086 0.24834027 0.2552835 ]
# Exploring: Taking a random action
# [0.24847053 0.24785607 0.24841543 0.25525797]
# Exploring: Taking a random action
# [0.24844568 0.24783129 0.24839059 0.25533244]
# Exploring: Taking a random action
# [0.24842084 0.24780651 0.24846574 0.25530691]
# Exploiting: Taking the best-known action
# [0.248396   0.24788172 0.2484409  0.25528138]
# Exploring: Taking a random action
# [0.25060973 0.25028412 0.24459609 0.25451006]
# Episode 25: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24902982 0.24556819 0.24926131 0.25614068]
# Exploiting: Taking the best-known action
# [0.24900492 0.24554363 0.24923639 0.25621506]
# Exploring: Taking a random action
# [0.24855345 0.24930315 0.24608078 0.25606262]
# Exploring: Taking a random action
# [0.24862858 0.24927822 0.24605618 0.25603702]
# Exploring: Taking a random action
# [0.24860372 0.24925329 0.24603157 0.25611141]
# Exploiting: Taking the best-known action
# [0.24835537 0.25000329 0.24578579 0.25585555]
# Exploring: Taking a random action
# [0.24981661 0.25023562 0.25002681 0.24992096]
# Exploiting: Taking the best-known action
# [0.24979163 0.2502106  0.25000181 0.24999596]
# Exploiting: Taking the best-known action
# [0.24936355 0.24767908 0.24905554 0.25390184]
# Exploiting: Taking the best-known action
# [0.25082567 0.24992305 0.2493277  0.24992358]
# Episode 26: Did not reach the goal. Total reward: -0.28
# Exploiting: Taking the best-known action
# [0.24898002 0.24551908 0.24921147 0.25628943]
# Exploring: Taking a random action
# [0.24833054 0.24997829 0.2458612  0.25582997]
# Exploiting: Taking the best-known action
# [0.24830571 0.2499533  0.24593661 0.25580439]
# Exploring: Taking a random action
# [0.24905512 0.24549453 0.24918655 0.2562638 ]
# Exploiting: Taking the best-known action
# [0.24903021 0.24546999 0.24916163 0.25633817]
# Exploiting: Taking the best-known action
# [0.24838087 0.2499283  0.24591202 0.25577881]
# Exploring: Taking a random action
# [0.24845602 0.24990331 0.24588743 0.25575324]
# Exploring: Taking a random action
# [0.24843118 0.24987833 0.24596283 0.25572766]
# Exploiting: Taking the best-known action
# [0.24840634 0.24985334 0.24593824 0.25580208]
# Exploiting: Taking the best-known action
# [0.25080644 0.24563559 0.2492869  0.25427107]
# Episode 27: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24900531 0.24544544 0.24913672 0.25641253]
# Exploiting: Taking the best-known action
# [0.24898041 0.2454209  0.24911181 0.25648688]
# Exploiting: Taking the best-known action
# [0.2483815  0.24982836 0.24591365 0.2558765 ]
# Exploring: Taking a random action
# [0.25088135 0.24561103 0.24926198 0.25424565]
# Exploiting: Taking the best-known action
# [0.25085626 0.24568646 0.24923705 0.25422022]
# Exploring: Taking a random action
# [0.24933861 0.24765431 0.24913062 0.25387645]
# Exploiting: Taking the best-known action
# [0.24941367 0.24762955 0.24910571 0.25385106]
# Exploring: Taking a random action
# [0.25083118 0.24566189 0.24931212 0.25419481]
# Exploiting: Taking the best-known action
# [0.2508061  0.24573732 0.24928719 0.25416939]
# Exploiting: Taking the best-known action
# [0.24938873 0.24760479 0.24908081 0.25392567]
# Episode 28: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24895552 0.24539636 0.2490869  0.25656122]
# Exploiting: Taking the best-known action
# [0.24835666 0.24980338 0.24588906 0.2559509 ]
# Exploiting: Taking the best-known action
# [0.25078102 0.24571275 0.24926227 0.25424396]
# Exploiting: Taking the best-known action
# [0.24837116 0.24795692 0.24841606 0.25525586]
# Exploiting: Taking the best-known action
# [0.25058467 0.25025909 0.24457164 0.2545846 ]
# Exploring: Taking a random action
# [0.24772663 0.24821899 0.25524097 0.24881341]
# Exploiting: Taking the best-known action
# [0.24770186 0.24829416 0.25521545 0.24878854]
# Exploiting: Taking the best-known action
# [0.24982538 0.25022537 0.25032356 0.2496257 ]
# Exploring: Taking a random action
# [0.23548776 0.29344255 0.23558193 0.23548776]
# Exploring: Taking a random action
# [0.2355642  0.29341321 0.23555837 0.23546421]
# Episode 29: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24893063 0.24537182 0.24906199 0.25663556]
# Exploring: Taking a random action
# [0.24843182 0.2497784  0.24586447 0.25592531]
# Exploring: Taking a random action
# [0.24840698 0.24975342 0.24583989 0.25599971]
# Exploring: Taking a random action
# [0.24848213 0.24972845 0.24581531 0.25597411]
# Exploiting: Taking the best-known action
# [0.24845729 0.24970348 0.24579073 0.25604851]
# Exploiting: Taking the best-known action
# [0.25075595 0.24578817 0.24923734 0.25421854]
# Exploring: Taking a random action
# [0.2493638  0.24758003 0.24915589 0.25390028]
# Exploring: Taking a random action
# [0.24933886 0.24765527 0.24913098 0.25387489]
# Exploring: Taking a random action
# [0.24931393 0.2476305  0.24920606 0.25384951]
# Exploiting: Taking the best-known action
# [0.249289   0.24760574 0.24918114 0.25392412]
# Episode 30: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24890573 0.24534729 0.24903709 0.25670989]
# Exploiting: Taking the best-known action
# [0.24843244 0.24967851 0.24576615 0.25612289]
# Exploiting: Taking the best-known action
# [0.25073087 0.24586358 0.24921242 0.25419312]
# Exploring: Taking a random action
# [0.24926408 0.24758098 0.24915622 0.25399872]
# Exploiting: Taking the best-known action
# [0.24933914 0.24755623 0.24913131 0.25397332]
# Exploring: Taking a random action
# [0.2507058  0.245839   0.24928749 0.25416771]
# Exploring: Taking a random action
# [0.25078072 0.24581442 0.24926257 0.25414229]
# Exploring: Taking a random action
# [0.25075565 0.24578984 0.24933763 0.25411688]
# Exploiting: Taking the best-known action
# [0.25073058 0.24586525 0.2493127  0.25409147]
# Exploiting: Taking the best-known action
# [0.24931421 0.24763147 0.2491064  0.25394792]
# Episode 31: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.24888085 0.24542275 0.24901219 0.25668422]
# Exploiting: Taking the best-known action
# [0.24885596 0.24539821 0.24898729 0.25675854]
# Exploiting: Taking the best-known action
# [0.2484076  0.24965355 0.24574158 0.25619727]
# Exploring: Taking a random action
# [0.2508055  0.24584067 0.24928777 0.25406606]
# Exploiting: Taking the best-known action
# [0.25078042 0.24581609 0.24926285 0.25414065]
# Exploiting: Taking the best-known action
# [0.24834633 0.24803212 0.24839122 0.25523033]
# Exploring: Taking a random action
# [0.25055961 0.25033406 0.24454718 0.25455914]
# Exploiting: Taking the best-known action
# [0.25053456 0.25030903 0.24452273 0.25463368]
# Exploiting: Taking the best-known action
# [0.24767709 0.24836932 0.25518993 0.24876366]
# Exploiting: Taking the best-known action
# [0.2498004  0.25030034 0.25029853 0.24960074]
# Episode 32: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24883108 0.24537367 0.2489624  0.25683286]
# Exploiting: Taking the best-known action
# [0.24838276 0.24962858 0.24571701 0.25627165]
# Exploiting: Taking the best-known action
# [0.25075534 0.2458915  0.24923792 0.25411524]
# Exploiting: Taking the best-known action
# [0.24928928 0.24760671 0.24908149 0.25402252]
# Exploiting: Taking the best-known action
# [0.25050951 0.250284   0.24449828 0.25470821]
# Exploring: Taking a random action
# [0.24775232 0.24834449 0.25516441 0.24873878]
# Exploring: Taking a random action
# [0.24782753 0.24831965 0.2551389  0.24871391]
# Exploiting: Taking the best-known action
# [0.24780275 0.24839481 0.25511339 0.24868904]
# Exploiting: Taking the best-known action
# [0.24977542 0.2503753  0.2502735  0.24957578]
# Exploiting: Taking the best-known action
# [0.23323188 0.30040912 0.23322611 0.23313288]
# Episode 33: Reached goal in 10 steps with total reward 0.91
# Exploiting: Taking the best-known action
# [0.2488062  0.24534913 0.2489375  0.25690717]
# Exploiting: Taking the best-known action
# [0.24835793 0.24960362 0.24569244 0.25634601]
# Exploiting: Taking the best-known action
# [0.25073027 0.24586691 0.249213   0.25418982]
# Exploiting: Taking the best-known action
# [0.2483215  0.24800732 0.24836638 0.2553048 ]
# Exploiting: Taking the best-known action
# [0.19932087 0.4012766  0.1985951  0.20080742]
# Exploiting: Taking the best-known action
# [0.24829667 0.24798252 0.24834155 0.25537926]
# Exploiting: Taking the best-known action
# [0.19940093 0.40123648 0.19857524 0.20078734]
# Exploiting: Taking the best-known action
# [0.19938099 0.40119636 0.19855539 0.20086726]
# Exploring: Taking a random action
# [0.19936106 0.40125624 0.19853554 0.20084717]
# Exploring: Taking a random action
# [0.19934112 0.40121611 0.19861567 0.20082709]
# Episode 34: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24878132 0.2453246  0.24891261 0.25698147]
# Exploring: Taking a random action
# [0.24833309 0.24957867 0.24566787 0.25642037]
# Exploiting: Taking the best-known action
# [0.24830826 0.24955371 0.2457433  0.25639473]
# Exploring: Taking a random action
# [0.24875644 0.24530007 0.24898771 0.25695577]
# Exploring: Taking a random action
# [0.24883156 0.24527554 0.24896281 0.25693008]
# Exploiting: Taking the best-known action
# [0.24880668 0.24525102 0.24893792 0.25700438]
# Exploiting: Taking the best-known action
# [0.24828344 0.24952876 0.24571872 0.25646908]
# Exploiting: Taking the best-known action
# [0.2507052  0.24594232 0.24918808 0.2541644 ]
# Exploiting: Taking the best-known action
# [0.24926436 0.24768194 0.24905659 0.25399712]
# Exploiting: Taking the best-known action
# [0.25090058 0.24989806 0.24930277 0.24989859]
# Episode 35: Did not reach the goal. Total reward: -0.10
# Exploring: Taking a random action
# [0.2487818  0.24532649 0.24891303 0.25697868]
# Exploiting: Taking the best-known action
# [0.24875693 0.24530196 0.24888814 0.25705298]
# Exploring: Taking a random action
# [0.24825861 0.2496038  0.24569415 0.25644344]
# Exploiting: Taking the best-known action
# [0.24823379 0.24957884 0.24566959 0.25651779]
# Exploiting: Taking the best-known action
# [0.25068013 0.24601771 0.24916317 0.25413899]
# Exploiting: Taking the best-known action
# [0.24923943 0.24765717 0.24903168 0.25407172]
# Exploiting: Taking the best-known action
# [0.25048446 0.25025898 0.24447383 0.25478273]
# Exploiting: Taking the best-known action
# [0.24777798 0.24846997 0.25508788 0.24866418]
# Exploiting: Taking the best-known action
# [0.24975044 0.25045025 0.25024848 0.24955082]
# Exploiting: Taking the best-known action
# [0.23092266 0.30733576 0.23091694 0.23082464]
# Episode 36: Reached goal in 10 steps with total reward 0.91
# Exploiting: Taking the best-known action
# [0.24873205 0.24527743 0.24886325 0.25712726]
# Exploring: Taking a random action
# [0.24820897 0.24955388 0.24574501 0.25649214]
# Exploiting: Taking the best-known action
# [0.24818415 0.24952893 0.24572044 0.25656648]
# Exploiting: Taking the best-known action
# [0.25065506 0.24599312 0.24913825 0.25421357]
# Exploiting: Taking the best-known action
# [0.24827184 0.24805771 0.24831672 0.25535373]
# Exploiting: Taking the best-known action
# [0.25045941 0.25023395 0.24444939 0.25485724]
# Exploiting: Taking the best-known action
# [0.2477532  0.24854511 0.25506237 0.24863931]
# Exploiting: Taking the best-known action
# [0.24972547 0.2505252  0.25022346 0.24952587]
# Exploiting: Taking the best-known action
# [0.2286363  0.31419382 0.22863063 0.22853925]
# Episode 37: Reached goal in 9 steps with total reward 0.92
# Exploring: Taking a random action
# [0.24880717 0.2452529  0.24883837 0.25710155]
# Exploiting: Taking the best-known action
# [0.24878229 0.24522838 0.24881349 0.25717584]
# Exploiting: Taking the best-known action
# [0.24815933 0.24950398 0.24569587 0.25664082]
# Exploiting: Taking the best-known action
# [0.25063    0.24606851 0.24911334 0.25418815]
# Exploiting: Taking the best-known action
# [0.24899044 0.24740976 0.2497819  0.2538179 ]
# Exploiting: Taking the best-known action
# [0.24976666 0.25018558 0.24997681 0.25007096]
# Exploiting: Taking the best-known action
# [0.24906553 0.24738502 0.24975692 0.25379252]
# Exploiting: Taking the best-known action
# [0.25060494 0.2460439  0.24908843 0.25426272]
# Exploring: Taking a random action
# [0.24834701 0.24803291 0.24829189 0.2553282 ]
# Exploiting: Taking the best-known action
# [0.24832217 0.2481081  0.24826706 0.25530267]
# Episode 38: Did not reach the goal. Total reward: -0.19
# Exploiting: Taking the best-known action
# [0.24875742 0.24520386 0.24878861 0.25725011]
# Exploiting: Taking the best-known action
# [0.24813452 0.24947903 0.2456713  0.25671515]
# Exploiting: Taking the best-known action
# [0.25057988 0.24611929 0.24906353 0.2542373 ]
# Exploring: Taking a random action
# [0.24904063 0.24736029 0.24983194 0.25376714]
# Exploiting: Taking the best-known action
# [0.24901573 0.24733555 0.24980696 0.25384176]
# Exploiting: Taking the best-known action
# [0.25043437 0.25020893 0.24442495 0.25493175]
# Exploiting: Taking the best-known action
# [0.24772843 0.24862025 0.25503687 0.24861445]
# Exploiting: Taking the best-known action
# [0.2497005  0.25060014 0.25019844 0.24950092]
# Exploiting: Taking the best-known action
# [0.22637257 0.32098398 0.22636696 0.22627648]
# Episode 39: Reached goal in 9 steps with total reward 0.92
# Exploiting: Taking the best-known action
# [0.24873254 0.24517934 0.24876373 0.25732438]
# Exploiting: Taking the best-known action
# [0.24810971 0.24945409 0.24564674 0.25678947]
# Exploiting: Taking the best-known action
# [0.25055483 0.24619467 0.24903862 0.25421188]
# Exploiting: Taking the best-known action
# [0.24899083 0.24731082 0.24978198 0.25391637]
# Exploiting: Taking the best-known action
# [0.25040933 0.25018391 0.24440051 0.25500625]
# Exploiting: Taking the best-known action
# [0.24770366 0.24869538 0.25501137 0.24858959]
# Exploiting: Taking the best-known action
# [0.24967553 0.25067507 0.25017342 0.24947597]
# Exploring: Taking a random action
# [0.22634993 0.32105188 0.22634433 0.22625386]
# Exploring: Taking a random action
# [0.22642729 0.32101978 0.2263217  0.22623123]
# Exploiting: Taking the best-known action
# [0.22418544 0.32774235 0.22408089 0.22399132]
# Episode 40: Reached goal in 10 steps with total reward 0.91
# Exploiting: Taking the best-known action
# [0.24870767 0.24515483 0.24873886 0.25739864]
# Exploring: Taking a random action
# [0.2480849  0.24952913 0.24562218 0.25676379]
# Exploiting: Taking the best-known action
# [0.24816008 0.24950418 0.24559762 0.25673812]
# Exploring: Taking a random action
# [0.24813527 0.24957923 0.24557306 0.25671245]
# Exploiting: Taking the best-known action
# [0.24811046 0.24955427 0.2455485  0.25678677]
# Exploiting: Taking the best-known action
# [0.25052977 0.24617006 0.24901372 0.25428645]
# Exploiting: Taking the best-known action
# [0.24829734 0.24818328 0.24824224 0.25527714]
# Exploiting: Taking the best-known action
# [0.25038429 0.2501589  0.24437607 0.25508074]
# Exploring: Taking a random action
# [0.24767889 0.24867051 0.25508586 0.24856474]
# Exploiting: Taking the best-known action
# [0.24765412 0.24874564 0.25506035 0.24853988]
# Episode 41: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24868281 0.24513031 0.24871399 0.25747289]
# Exploiting: Taking the best-known action
# [0.24808565 0.24952932 0.24552395 0.25686108]
# Exploiting: Taking the best-known action
# [0.25050472 0.24624543 0.24898882 0.25426102]
# Exploiting: Taking the best-known action
# [0.24896593 0.24728609 0.24975701 0.25399097]
# Exploiting: Taking the best-known action
# [0.25035926 0.25013388 0.24435163 0.25515523]
# Exploiting: Taking the best-known action
# [0.24762936 0.24882076 0.25503485 0.24851503]
# Exploring: Taking a random action
# [0.24965057 0.25065001 0.25024839 0.24945103]
# Exploring: Taking a random action
# [0.24962561 0.25072494 0.25022337 0.24942609]
# Exploiting: Taking the best-known action
# [0.24960065 0.25079986 0.25019835 0.24940115]
# Exploiting: Taking the best-known action
# [0.22196578 0.33439837 0.22186227 0.22177358]
# Episode 42: Reached goal in 10 steps with total reward 0.91
# Exploiting: Taking the best-known action
# [0.24865794 0.2451058  0.24868912 0.25754714]
# Exploiting: Taking the best-known action
# [0.24806084 0.24950437 0.2454994  0.25693539]
# Exploiting: Taking the best-known action
# [0.25047968 0.2463208  0.24896393 0.2542356 ]
# Exploiting: Taking the best-known action
# [0.24894104 0.24726137 0.24973203 0.25406556]
# Exploiting: Taking the best-known action
# [0.25033422 0.25010887 0.2443272  0.2552297 ]
# Exploiting: Taking the best-known action
# [0.2476046  0.24889587 0.25500935 0.24849018]
# Exploiting: Taking the best-known action
# [0.24957569 0.25087477 0.25017333 0.24937621]
# Exploiting: Taking the best-known action
# [0.2197681  0.34098849 0.21966561 0.21957781]
# Episode 43: Reached goal in 8 steps with total reward 0.93
# Exploiting: Taking the best-known action
# [0.24863308 0.24508129 0.24876424 0.25752139]
# Exploiting: Taking the best-known action
# [0.24860822 0.24505679 0.24873937 0.25759563]
# Exploring: Taking a random action
# [0.24803604 0.24947942 0.24547486 0.25700969]
# Exploiting: Taking the best-known action
# [0.24811123 0.24945447 0.24545031 0.25698399]
# Exploiting: Taking the best-known action
# [0.24808642 0.24942953 0.24552576 0.25695829]
# Exploiting: Taking the best-known action
# [0.24858336 0.24503229 0.2487145  0.25766986]
# Exploiting: Taking the best-known action
# [0.24806161 0.24940459 0.24550121 0.25703259]
# Exploiting: Taking the best-known action
# [0.25045463 0.24639616 0.24893903 0.25421018]
# Exploiting: Taking the best-known action
# [0.24891615 0.24723664 0.24970706 0.25414015]
# Exploiting: Taking the best-known action
# [0.25030919 0.25008386 0.24430277 0.25530417]
# Episode 44: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.2485585  0.24510777 0.24868963 0.25764409]
# Exploiting: Taking the best-known action
# [0.2503566  0.2495551  0.24964999 0.25043831]
# Exploiting: Taking the best-known action
# [0.24853365 0.24518326 0.24866476 0.25761833]
# Exploiting: Taking the best-known action
# [0.25043156 0.24953014 0.24962503 0.25041327]
# Exploiting: Taking the best-known action
# [0.2485088  0.24525873 0.2486399  0.25759257]
# Exploiting: Taking the best-known action
# [0.25050651 0.24950519 0.24960007 0.25038823]
# Exploiting: Taking the best-known action
# [0.24848395 0.2453342  0.24861504 0.25756682]
# Exploiting: Taking the best-known action
# [0.25058145 0.24948025 0.24957511 0.25036319]
# Exploiting: Taking the best-known action
# [0.2484591  0.24540966 0.24859018 0.25754106]
# Exploiting: Taking the best-known action
# [0.25065638 0.2494553  0.24955016 0.25033816]
# Episode 45: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24843426 0.24548511 0.24856532 0.25751531]
# Exploiting: Taking the best-known action
# [0.25073131 0.24943036 0.2495252  0.25031313]
# Exploiting: Taking the best-known action
# [0.24840942 0.24556055 0.24854047 0.25748956]
# Exploring: Taking a random action
# [0.25070624 0.24940542 0.24960024 0.2502881 ]
# Exploiting: Taking the best-known action
# [0.25078116 0.24938048 0.24957529 0.25026307]
# Exploiting: Taking the best-known action
# [0.24838458 0.24563599 0.24851562 0.25746382]
# Exploiting: Taking the best-known action
# [0.25085608 0.24935554 0.24955033 0.25023805]
# Exploiting: Taking the best-known action
# [0.24835974 0.24561143 0.24849077 0.25753806]
# Exploiting: Taking the best-known action
# [0.24803681 0.24937965 0.24547666 0.25710688]
# Exploiting: Taking the best-known action
# [0.25042959 0.24647151 0.24891414 0.25418476]
# Episode 46: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.2484349  0.24558687 0.24846592 0.25751231]
# Exploiting: Taking the best-known action
# [0.24841006 0.24556231 0.24844108 0.25758655]
# Exploring: Taking a random action
# [0.24801201 0.24945471 0.24545211 0.25708117]
# Exploiting: Taking the best-known action
# [0.24798721 0.24942976 0.24542757 0.25715545]
# Exploiting: Taking the best-known action
# [0.25040455 0.24654686 0.24888925 0.25415934]
# Exploiting: Taking the best-known action
# [0.24889126 0.24721192 0.24968209 0.25421472]
# Exploiting: Taking the best-known action
# [0.25028416 0.25005886 0.24427834 0.25537864]
# Exploiting: Taking the best-known action
# [0.24757984 0.24897097 0.25498385 0.24846534]
# Exploiting: Taking the best-known action
# [0.24955073 0.25094967 0.25014832 0.24935127]
# Exploiting: Taking the best-known action
# [0.21759218 0.34751335 0.2174907  0.21740377]
# Episode 47: Reached goal in 10 steps with total reward 0.91
# Exploiting: Taking the best-known action
# [0.24838522 0.24553776 0.24851622 0.2575608 ]
# Exploiting: Taking the best-known action
# [0.24836039 0.24551321 0.24849138 0.25763503]
# Exploiting: Taking the best-known action
# [0.24796241 0.24940482 0.24540303 0.25722973]
# Exploiting: Taking the best-known action
# [0.25037951 0.2466222  0.24886436 0.25413393]
# Exploiting: Taking the best-known action
# [0.24886637 0.2471872  0.24965713 0.2542893 ]
# Exploiting: Taking the best-known action
# [0.25025914 0.25003386 0.24425392 0.25545309]
# Exploiting: Taking the best-known action
# [0.24755509 0.24904607 0.25495835 0.24844049]
# Exploiting: Taking the best-known action
# [0.24952578 0.25102457 0.25012331 0.24932634]
# Exploiting: Taking the best-known action
# [0.2154378  0.35397362 0.21533733 0.21525126]
# Episode 48: Reached goal in 9 steps with total reward 0.92
# Exploiting: Taking the best-known action
# [0.24833555 0.24558865 0.24846653 0.25760927]
# Exploiting: Taking the best-known action
# [0.25093098 0.24933061 0.24952538 0.25021303]
# Exploiting: Taking the best-known action
# [0.24831072 0.24556409 0.24844168 0.2576835 ]
# Exploiting: Taking the best-known action
# [0.24793762 0.24937989 0.24537849 0.257304  ]
# Exploiting: Taking the best-known action
# [0.25035447 0.24669753 0.24883948 0.25410852]
# Exploiting: Taking the best-known action
# [0.24884149 0.24716249 0.24963217 0.25436386]
# Exploiting: Taking the best-known action
# [0.25023411 0.25000885 0.24422949 0.25552754]
# Exploiting: Taking the best-known action
# [0.24753033 0.24912115 0.25493286 0.24841565]
# Exploiting: Taking the best-known action
# [0.24950083 0.25109946 0.2500983  0.24930141]
# Exploring: Taking a random action
# [0.21541626 0.35393822 0.2153158  0.21532972]
# Episode 49: Did not reach the goal. Total reward: -0.10
# Exploiting: Taking the best-known action
# [0.24828589 0.24553954 0.24841684 0.25775773]
# Exploiting: Taking the best-known action
# [0.24791283 0.24935495 0.24535396 0.25737826]
# Exploiting: Taking the best-known action
# [0.25032944 0.24677285 0.2488146  0.25408311]
# Exploiting: Taking the best-known action
# [0.24881661 0.24713777 0.24960721 0.25443842]
# Exploiting: Taking the best-known action
# [0.25020909 0.24998386 0.24420507 0.25560198]
# Exploring: Taking a random action
# [0.24750558 0.24919623 0.25490737 0.24839081]
# Exploiting: Taking the best-known action
# [0.24748084 0.24927131 0.25488188 0.24836597]
# Exploiting: Taking the best-known action
# [0.24947588 0.25117434 0.25007329 0.24927648]
# Exploiting: Taking the best-known action
# [0.21328342 0.36033487 0.21318396 0.21319774]
# Episode 50: Reached goal in 9 steps with total reward 0.92
# Final Q-table:
# [[[-0.03401995 -0.03403374 -0.0341574  -0.03380775]
#   [-0.0279909  -0.03194019 -0.02868105 -0.02700402]
#   [-0.02014824 -0.01575887 -0.01960046 -0.0194977 ]
#   [-0.01461754 -0.01179257 -0.01518871 -0.0135126 ]
#   [-0.00688817 -0.00727995 -0.00819965 -0.00723444]]
#
#  [[-0.03213748 -0.03302675 -0.03142413 -0.03540375]
#   [-0.03687171 -0.03857458 -0.03843656 -0.00845194]
#   [-0.01376993 -0.01263725 -0.02160806  0.00894462]
#   [-0.01001554 -0.01427664 -0.00947752  0.07299327]
#   [-0.002447    0.20792408  0.00215244 -0.00528117]]
#
#  [[-0.03190089 -0.03143307 -0.03139236 -0.03320296]
#   [-0.02137898 -0.01486716 -0.01568188 -0.01522217]
#   [-0.01263155 -0.01362475 -0.01247152 -0.01326943]
#   [-0.00979832 -0.01       -0.00994512 -0.00945412]
#   [-0.00385318  0.46746631  0.01770008 -0.0029701 ]]
#
#  [[-0.02749616 -0.02801185 -0.02713227 -0.02613506]
#   [-0.01791919 -0.01840071 -0.01888471 -0.01862612]
#   [-0.001      -0.02680339 -0.00176999  0.        ]
#   [-0.01        0.          0.          0.        ]
#   [ 0.09150495  0.80783226 -0.002881    0.06800123]]
#
#  [[-0.01896334 -0.02191895 -0.01856398 -0.01883297]
#   [-0.01681166 -0.01693337 -0.01732084 -0.01721181]
#   [-0.01539298 -0.01280405 -0.01290804 -0.0037352 ]
#   [-0.01114111 -0.00585199 -0.00666307  0.18511094]
#   [-0.0019     -0.00199    -0.001      -0.001     ]]]
# Final Policy Probabilities:
# [[[0.24828589 0.24553954 0.24841684 0.25775773]
#   [0.24791283 0.24935495 0.24535396 0.25737826]
#   [0.25032944 0.24677285 0.2488146  0.25408311]
#   [0.24829734 0.24818328 0.24824224 0.25527714]
#   [0.19934112 0.40121611 0.19861567 0.20082709]]
#
#  [[0.25093098 0.24933061 0.24952538 0.25021303]
#   [0.24976666 0.25018558 0.24997681 0.25007096]
#   [0.24881661 0.24713777 0.24960721 0.25443842]
#   [0.25020909 0.24998386 0.24420507 0.25560198]
#   [0.24748084 0.24927131 0.25488188 0.24836597]]
#
#  [[0.2489836  0.25147081 0.24878493 0.25076066]
#   [0.25079536 0.24960196 0.24940179 0.25020089]
#   [0.25090058 0.24989806 0.24930277 0.24989859]
#   [0.25147362 0.2494744  0.24957639 0.24947559]
#   [0.24947588 0.25117434 0.25007329 0.24927648]]
#
#  [[0.24895726 0.25074225 0.24955169 0.25074881]
#   [0.2504497  0.2496522  0.24955163 0.25034647]
#   [0.24927661 0.25226993 0.24927673 0.24917674]
#   [0.25074925 0.24975025 0.24975025 0.24975025]
#   [0.21328342 0.36033487 0.21318396 0.21319774]]
#
#  [[0.24940285 0.25029935 0.24970024 0.25059756]
#   [0.25044871 0.24994925 0.24955158 0.25005046]
#   [0.25072021 0.24972581 0.24952747 0.25002651]
#   [0.24563566 0.24485408 0.24485419 0.26465607]
#   [0.25005    0.25004997 0.24995    0.24995002]]]
