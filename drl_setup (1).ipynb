# %% [markdown]
# # Mock Dataset

# %%
import pandas as pd
import random

def generate_mock_data(num_samples=1000):
    """
    Generate a mock dataset for caregiver interactions.
    Each row represents a simulated interaction.
    """
    data = []
    for _ in range(num_samples):
        # Randomly assign state components
        sentiment = random.choice([-1, 0, 1])  # Negative, Neutral, Positive
        time_of_day = random.choice([0, 1, 2])  # Morning, Evening, Night
        query_type = random.choice(["emotional", "practical", "mixed"])

        # Simulate agent actions and rewards
        if sentiment == -1:  # Caregiver is stressed
            action = random.choice([0, 2])  # Emotional or Mixed preferred
            reward = 2 if action == 0 else 1
        elif sentiment == 0:  # Caregiver is neutral
            action = random.choice([1, 2])  # Logical or Mixed preferred
            reward = 2 if action == 1 else 1
        else:  # Caregiver is positive
            action = random.choice([0, 1, 2])  # Any response is okay
            reward = 2 if action == random.choice([0, 1, 2]) else 1

        # Append row to dataset
        data.append([sentiment, time_of_day, query_type, action, reward])

    # Convert to DataFrame
    df = pd.DataFrame(data, columns=["Sentiment", "TimeOfDay", "QueryType", "Action", "Reward"])
    return df

# Generate and save mock data
mock_data = generate_mock_data(1000)
mock_data.to_csv("mock_caregiver_data.csv", index=False)
print("Mock dataset created and saved as 'mock_caregiver_data.csv'")
# Out:
# Mock dataset created and saved as 'mock_caregiver_data.csv'

# %% [markdown]
# # Creating Custom Environment

# %%
import gymnasium as gym
import numpy as np

class CaregiverEnvWithDataset(gym.Env):
    def __init__(self, dataset_path):
        super(CaregiverEnvWithDataset, self).__init__()
        self.data = pd.read_csv(dataset_path)
        self.current_index = 0
        self.action_space = gym.spaces.Discrete(3)  # Actions: Emotional, Logical, Mixed
        self.observation_space = gym.spaces.Box(low=-1, high=2, shape=(3,), dtype=np.float32)

    def reset(self):
        # Reset to the first row of the dataset
        self.current_index = 0
        row = self.data.iloc[self.current_index]
        sentiment = row["Sentiment"]
        time_of_day = row["TimeOfDay"]
        last_action = -1  # No action yet
        self.current_state = np.array([sentiment, time_of_day, last_action], dtype=np.float32)
        return self.current_state

    def step(self, action):
        # Get current row from the dataset
        row = self.data.iloc[self.current_index]
        sentiment = row["Sentiment"]
        time_of_day = row["TimeOfDay"]
        reward = row["Reward"] if row["Action"] == action else -1  # Penalize mismatched actions

        # Update sentiment (simulate change)
        sentiment += np.random.uniform(-0.1, 0.2)  # Simulate small changes in sentiment
        sentiment = np.clip(sentiment, -1, 1)

        # Update state and index
        self.current_state = np.array([sentiment, time_of_day, action], dtype=np.float32)
        self.current_index += 1
        done = self.current_index >= len(self.data)
        truncated = False  # Add truncated flag (no truncation logic for now)

        return self.current_state, reward, done, truncated, {}


# Example usage
env = CaregiverEnvWithDataset("mock_caregiver_data.csv")
state = env.reset()

# %% [markdown]
# # Calculate reward function

# %%
def calculate_reward(sentiment, action, time_of_day):
    """
    Calculates the reward based on the sentiment, action taken, and time of day.
    """
    # Reward for matching response type to sentiment
    if action == 0 and sentiment == -1:  # Emotional support for negative sentiment
        reward = 2
    elif action == 1 and sentiment == 0:  # Logical response for neutral sentiment
        reward = 2
    elif action == 2:  # Mixed response for any sentiment
        reward = 1
    else:
        reward = -1  # Mismatched response

    # Additional reward for matching time-of-day context
    if time_of_day == 2 and action == 0:  # Nighttime prefers emotional responses
        reward += 1
    elif time_of_day == 0 and action == 1:  # Morning prefers logical responses
        reward += 1

    return reward

# %% [markdown]
# # Action selection

# %%
import random
import numpy as np
import torch

def select_action(state, q_network, epsilon, action_space_size):
    """
    Selects an action based on epsilon-greedy policy.
    """
    if random.random() < epsilon:  # Exploration
        return random.randint(0, action_space_size - 1)
    else:  # Exploitation
        state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)  # Add batch dimension
        q_values = q_network(state_tensor)  # Predict Q-values
        return torch.argmax(q_values).item()

# %% [markdown]
# # DQN

# %%
import torch
import torch.nn as nn

class DQN(nn.Module):
    def __init__(self, state_dim, action_dim):
        super(DQN, self).__init__()
        self.fc1 = nn.Linear(state_dim, 128)
        self.fc2 = nn.Linear(128, 128)
        self.fc3 = nn.Linear(128, action_dim)
    
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)  # Output Q-values for each action

# %% [markdown]
# # Replay buffer stores past experience for training

# %%
from collections import deque
import random

class ReplayBuffer:
    def __init__(self, capacity):
        self.buffer = deque(maxlen=capacity)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        return random.sample(self.buffer, batch_size)

    def size(self):
        return len(self.buffer)

# %% [markdown]
# # Training loop for DQN

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch.optim as optim

# Hyperparameters
hyperparameters = {
    "learning_rate": 1e-3,
    "gamma": 0.99,                   # Discount factor
    "epsilon": 1.0,                  # Initial exploration rate
    "epsilon_decay": 0.995,          # Decay rate for epsilon
    "min_epsilon": 0.1,              # Minimum exploration rate
    "batch_size": 64,
    "replay_buffer_capacity": 10000,
    "target_update_interval": 10     # Update target network every 10 episodes
}

# Initialize components
state_dim = 3  # Example: [sentiment, time of day, last action]
action_dim = 3  # Example: 3 actions (emotional, logical, mixed)
q_network = DQN(state_dim, action_dim)
target_network = DQN(state_dim, action_dim)
target_network.load_state_dict(q_network.state_dict())  # Sync target network
replay_buffer = ReplayBuffer(hyperparameters["replay_buffer_capacity"])
optimizer = optim.Adam(q_network.parameters(), lr=hyperparameters["learning_rate"])

# Training variables
epsilon = hyperparameters["epsilon"]
episode_rewards = []

# Training loop
for episode in range(1000):  # Number of episodes
    state = env.reset()  # Reset environment
    total_reward = 0

    for t in range(100):  # Max steps per episode
        # Select action (epsilon-greedy)
        if np.random.rand() < epsilon:
            action = np.random.randint(action_dim)  # Random action (exploration)
        else:
            state_tensor = torch.tensor(state, dtype=torch.float32).unsqueeze(0)
            q_values = q_network(state_tensor).detach().numpy()
            action = np.argmax(q_values)  # Exploitation

        # Take action in environment
        obs, reward, done, truncated, _ = env.step(action)
        replay_buffer.add((state, action, reward, obs, done or truncated))
        total_reward += reward

        # Train if replay buffer is ready
        if replay_buffer.size() >= hyperparameters["batch_size"]:
            # Sample batch from replay buffer
            batch = replay_buffer.sample(hyperparameters["batch_size"])
            states, actions, rewards, next_states, dones = zip(*batch)

            # Convert to tensors
            states_tensor = torch.tensor(states, dtype=torch.float32)
            actions_tensor = torch.tensor(actions, dtype=torch.long).unsqueeze(1)
            rewards_tensor = torch.tensor(rewards, dtype=torch.float32).unsqueeze(1)
            next_states_tensor = torch.tensor(next_states, dtype=torch.float32)
            dones_tensor = torch.tensor(dones, dtype=torch.float32).unsqueeze(1)

            # Compute target Q-values
            with torch.no_grad():
                target_q_values = rewards_tensor + hyperparameters["gamma"] * torch.max(target_network(next_states_tensor), dim=1)[0].unsqueeze(1) * (1 - dones_tensor)

            # Compute current Q-values
            current_q_values = q_network(states_tensor).gather(1, actions_tensor)

            # Compute loss
            loss = torch.nn.functional.mse_loss(current_q_values, target_q_values)

            # Optimize Q-network
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        # Update state
        state = obs

        if done or truncated:
            break

    # Update epsilon
    epsilon = max(hyperparameters["min_epsilon"], epsilon * hyperparameters["epsilon_decay"])

    # Update target network periodically
    if episode % hyperparameters["target_update_interval"] == 0:
        target_network.load_state_dict(q_network.state_dict())

    # Log total reward
    episode_rewards.append(total_reward)
    print(f"Episode {episode}: Total Reward = {total_reward}")

# Plot training progress
plt.figure(figsize=(10, 6))
plt.plot(episode_rewards, label="Total Reward per Episode")
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Training Progress")
plt.legend()
plt.grid()
plt.show()
# Out:
# /var/folders/6n/_3v7211x5hj3mg4qs5wn4yph0000gn/T/ipykernel_286/580883106.py:56: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:281.)
#   states_tensor = torch.tensor(states, dtype=torch.float32)
# Episode 0: Total Reward = -24
# Episode 1: Total Reward = -37
# Episode 2: Total Reward = -23
# Episode 3: Total Reward = -10
# Episode 4: Total Reward = -18
# Episode 5: Total Reward = -23
# Episode 6: Total Reward = -14
# Episode 7: Total Reward = -19
# Episode 8: Total Reward = -8
# Episode 9: Total Reward = -7
# Episode 10: Total Reward = -15
# Episode 11: Total Reward = -35
# Episode 12: Total Reward = -16
# Episode 13: Total Reward = -9
# Episode 14: Total Reward = -26
# Episode 15: Total Reward = -27
# Episode 16: Total Reward = 1
# Episode 17: Total Reward = -20
# Episode 18: Total Reward = -18
# Episode 19: Total Reward = 9
# Episode 20: Total Reward = -20
# Episode 21: Total Reward = -22
# Episode 22: Total Reward = -11
# Episode 23: Total Reward = -21
# Episode 24: Total Reward = -8
# Episode 25: Total Reward = -3
# Episode 26: Total Reward = 8
# Episode 27: Total Reward = -26
# Episode 28: Total Reward = -4
# Episode 29: Total Reward = -47
# Episode 30: Total Reward = -8
# Episode 31: Total Reward = -25
# Episode 32: Total Reward = -31
# Episode 33: Total Reward = -6
# Episode 34: Total Reward = -3
# Episode 35: Total Reward = -14
# Episode 36: Total Reward = -39
# Episode 37: Total Reward = -5
# Episode 38: Total Reward = 3
# Episode 39: Total Reward = -28
# Episode 40: Total Reward = -9
# Episode 41: Total Reward = -10
# Episode 42: Total Reward = -26
# Episode 43: Total Reward = -22
# Episode 44: Total Reward = -6
# Episode 45: Total Reward = -18
# Episode 46: Total Reward = -22
# Episode 47: Total Reward = 0
# Episode 48: Total Reward = -10
# Episode 49: Total Reward = -9
# Episode 50: Total Reward = -26
# Episode 51: Total Reward = -10
# Episode 52: Total Reward = -20
# Episode 53: Total Reward = -33
# Episode 54: Total Reward = -9
# Episode 55: Total Reward = -3
# Episode 56: Total Reward = -29
# Episode 57: Total Reward = -1
# Episode 58: Total Reward = 1
# Episode 59: Total Reward = 8
# Episode 60: Total Reward = -1
# Episode 61: Total Reward = -18
# Episode 62: Total Reward = -34
# Episode 63: Total Reward = -27
# Episode 64: Total Reward = -17
# Episode 65: Total Reward = -4
# Episode 66: Total Reward = -12
# Episode 67: Total Reward = -1
# Episode 68: Total Reward = -9
# Episode 69: Total Reward = -15
# Episode 70: Total Reward = -8
# Episode 71: Total Reward = 4
# Episode 72: Total Reward = -5
# Episode 73: Total Reward = 5
# Episode 74: Total Reward = 3
# Episode 75: Total Reward = -27
# Episode 76: Total Reward = 2
# Episode 77: Total Reward = -14
# Episode 78: Total Reward = -9
# Episode 79: Total Reward = -9
# Episode 80: Total Reward = 4
# Episode 81: Total Reward = 7
# Episode 82: Total Reward = -22
# Episode 83: Total Reward = -12
# Episode 84: Total Reward = -7
# Episode 85: Total Reward = -9
# Episode 86: Total Reward = 3
# Episode 87: Total Reward = -15
# Episode 88: Total Reward = 3
# Episode 89: Total Reward = -20
# Episode 90: Total Reward = -5
# Episode 91: Total Reward = -13
# Episode 92: Total Reward = -18
# Episode 93: Total Reward = 5
# Episode 94: Total Reward = -3
# Episode 95: Total Reward = -34
# Episode 96: Total Reward = 0
# Episode 97: Total Reward = 8
# Episode 98: Total Reward = -8
# Episode 99: Total Reward = -2
# Episode 100: Total Reward = 5
# Episode 101: Total Reward = 2
# Episode 102: Total Reward = 3
# Episode 103: Total Reward = 10
# Episode 104: Total Reward = 5
# Episode 105: Total Reward = -8
# Episode 106: Total Reward = -8
# Episode 107: Total Reward = -11
# Episode 108: Total Reward = -15
# Episode 109: Total Reward = -17
# Episode 110: Total Reward = 7
# Episode 111: Total Reward = -13
# Episode 112: Total Reward = -16
# Episode 113: Total Reward = -14
# Episode 114: Total Reward = 2
# Episode 115: Total Reward = -2
# Episode 116: Total Reward = -20
# Episode 117: Total Reward = 14
# Episode 118: Total Reward = -9
# Episode 119: Total Reward = -7
# Episode 120: Total Reward = 7
# Episode 121: Total Reward = -4
# Episode 122: Total Reward = -2
# Episode 123: Total Reward = -21
# Episode 124: Total Reward = 3
# Episode 125: Total Reward = -11
# Episode 126: Total Reward = -4
# Episode 127: Total Reward = -13
# Episode 128: Total Reward = -9
# Episode 129: Total Reward = 14
# Episode 130: Total Reward = -16
# Episode 131: Total Reward = -8
# Episode 132: Total Reward = -27
# Episode 133: Total Reward = 21
# Episode 134: Total Reward = -18
# Episode 135: Total Reward = -16
# Episode 136: Total Reward = 5
# Episode 137: Total Reward = -7
# Episode 138: Total Reward = -13
# Episode 139: Total Reward = -8
# Episode 140: Total Reward = 2
# Episode 141: Total Reward = 16
# Episode 142: Total Reward = -5
# Episode 143: Total Reward = -2
# Episode 144: Total Reward = 7
# Episode 145: Total Reward = -3
# Episode 146: Total Reward = 0
# Episode 147: Total Reward = -10
# Episode 148: Total Reward = 8
# Episode 149: Total Reward = -1
# Episode 150: Total Reward = -5
# Episode 151: Total Reward = 7
# Episode 152: Total Reward = -13
# Episode 153: Total Reward = 7
# Episode 154: Total Reward = 15
# Episode 155: Total Reward = -4
# Episode 156: Total Reward = 0
# Episode 157: Total Reward = 12
# Episode 158: Total Reward = -3
# Episode 159: Total Reward = -10
# Episode 160: Total Reward = -16
# Episode 161: Total Reward = 3
# Episode 162: Total Reward = 11
# Episode 163: Total Reward = 5
# Episode 164: Total Reward = 9
# Episode 165: Total Reward = 4
# Episode 166: Total Reward = -3
# Episode 167: Total Reward = -8
# Episode 168: Total Reward = -10
# Episode 169: Total Reward = -7
# Episode 170: Total Reward = 1
# Episode 171: Total Reward = 6
# Episode 172: Total Reward = 8
# Episode 173: Total Reward = -3
# Episode 174: Total Reward = 13
# Episode 175: Total Reward = 6
# Episode 176: Total Reward = 12
# Episode 177: Total Reward = 12
# Episode 178: Total Reward = -10
# Episode 179: Total Reward = 3
# Episode 180: Total Reward = -24
# Episode 181: Total Reward = 0
# Episode 182: Total Reward = -5
# Episode 183: Total Reward = 5
# Episode 184: Total Reward = -5
# Episode 185: Total Reward = 11
# Episode 186: Total Reward = -5
# Episode 187: Total Reward = 6
# Episode 188: Total Reward = -12
# Episode 189: Total Reward = -10
# Episode 190: Total Reward = -4
# Episode 191: Total Reward = -1
# Episode 192: Total Reward = -23
# Episode 193: Total Reward = 13
# Episode 194: Total Reward = -6
# Episode 195: Total Reward = 19
# Episode 196: Total Reward = -5
# Episode 197: Total Reward = 6
# Episode 198: Total Reward = 2
# Episode 199: Total Reward = 4
# Episode 200: Total Reward = 12
# Episode 201: Total Reward = -5
# Episode 202: Total Reward = 6
# Episode 203: Total Reward = -11
# Episode 204: Total Reward = 10
# Episode 205: Total Reward = 4
# Episode 206: Total Reward = 6
# Episode 207: Total Reward = -12
# Episode 208: Total Reward = 1
# Episode 209: Total Reward = 1
# Episode 210: Total Reward = 16
# Episode 211: Total Reward = 0
# Episode 212: Total Reward = -12
# Episode 213: Total Reward = 0
# Episode 214: Total Reward = 3
# Episode 215: Total Reward = -10
# Episode 216: Total Reward = -10
# Episode 217: Total Reward = 6
# Episode 218: Total Reward = 16
# Episode 219: Total Reward = -10
# Episode 220: Total Reward = 5
# Episode 221: Total Reward = -2
# Episode 222: Total Reward = 6
# Episode 223: Total Reward = -12
# Episode 224: Total Reward = -4
# Episode 225: Total Reward = 1
# Episode 226: Total Reward = -2
# Episode 227: Total Reward = 2
# Episode 228: Total Reward = 17
# Episode 229: Total Reward = 7
# Episode 230: Total Reward = 18
# Episode 231: Total Reward = -12
# Episode 232: Total Reward = 26
# Episode 233: Total Reward = 15
# Episode 234: Total Reward = -2
# Episode 235: Total Reward = 16
# Episode 236: Total Reward = 2
# Episode 237: Total Reward = 10
# Episode 238: Total Reward = 20
# Episode 239: Total Reward = 2
# Episode 240: Total Reward = 7
# Episode 241: Total Reward = -17
# Episode 242: Total Reward = 16
# Episode 243: Total Reward = 9
# Episode 244: Total Reward = 0
# Episode 245: Total Reward = 17
# Episode 246: Total Reward = 4
# Episode 247: Total Reward = 15
# Episode 248: Total Reward = 17
# Episode 249: Total Reward = -17
# Episode 250: Total Reward = -6
# Episode 251: Total Reward = -8
# Episode 252: Total Reward = 6
# Episode 253: Total Reward = 10
# Episode 254: Total Reward = 27
# Episode 255: Total Reward = 8
# Episode 256: Total Reward = 5
# Episode 257: Total Reward = 8
# Episode 258: Total Reward = -6
# Episode 259: Total Reward = 7
# Episode 260: Total Reward = 6
# Episode 261: Total Reward = 6
# Episode 262: Total Reward = 9
# Episode 263: Total Reward = 2
# Episode 264: Total Reward = -2
# Episode 265: Total Reward = 16
# Episode 266: Total Reward = 25
# Episode 267: Total Reward = 2
# Episode 268: Total Reward = 18
# Episode 269: Total Reward = 10
# Episode 270: Total Reward = 0
# Episode 271: Total Reward = -7
# Episode 272: Total Reward = 5
# Episode 273: Total Reward = 0
# Episode 274: Total Reward = 15
# Episode 275: Total Reward = -10
# Episode 276: Total Reward = 23
# Episode 277: Total Reward = 5
# Episode 278: Total Reward = 17
# Episode 279: Total Reward = 8
# Episode 280: Total Reward = 2
# Episode 281: Total Reward = 25
# Episode 282: Total Reward = 2
# Episode 283: Total Reward = 11
# Episode 284: Total Reward = 25
# Episode 285: Total Reward = 1
# Episode 286: Total Reward = 8
# Episode 287: Total Reward = 0
# Episode 288: Total Reward = 2
# Episode 289: Total Reward = 7
# Episode 290: Total Reward = -12
# Episode 291: Total Reward = 4
# Episode 292: Total Reward = -4
# Episode 293: Total Reward = 5
# Episode 294: Total Reward = 23
# Episode 295: Total Reward = 17
# Episode 296: Total Reward = 5
# Episode 297: Total Reward = 8
# Episode 298: Total Reward = 11
# Episode 299: Total Reward = 5
# Episode 300: Total Reward = 28
# Episode 301: Total Reward = 20
# Episode 302: Total Reward = 4
# Episode 303: Total Reward = 10
# Episode 304: Total Reward = 7
# Episode 305: Total Reward = 25
# Episode 306: Total Reward = 2
# Episode 307: Total Reward = -2
# Episode 308: Total Reward = 12
# Episode 309: Total Reward = 26
# Episode 310: Total Reward = 30
# Episode 311: Total Reward = 22
# Episode 312: Total Reward = -14
# Episode 313: Total Reward = 13
# Episode 314: Total Reward = 34
# Episode 315: Total Reward = -8
# Episode 316: Total Reward = 5
# Episode 317: Total Reward = 3
# Episode 318: Total Reward = 27
# Episode 319: Total Reward = 26
# Episode 320: Total Reward = 26
# Episode 321: Total Reward = 6
# Episode 322: Total Reward = 14
# Episode 323: Total Reward = 5
# Episode 324: Total Reward = 3
# Episode 325: Total Reward = 19
# Episode 326: Total Reward = 5
# Episode 327: Total Reward = 13
# Episode 328: Total Reward = -3
# Episode 329: Total Reward = 12
# Episode 330: Total Reward = 6
# Episode 331: Total Reward = 7
# Episode 332: Total Reward = 16
# Episode 333: Total Reward = 0
# Episode 334: Total Reward = 4
# Episode 335: Total Reward = 29
# Episode 336: Total Reward = 24
# Episode 337: Total Reward = 17
# Episode 338: Total Reward = 26
# Episode 339: Total Reward = 13
# Episode 340: Total Reward = 43
# Episode 341: Total Reward = 4
# Episode 342: Total Reward = 12
# Episode 343: Total Reward = 21
# Episode 344: Total Reward = 30
# Episode 345: Total Reward = -7
# Episode 346: Total Reward = 11
# Episode 347: Total Reward = 29
# Episode 348: Total Reward = 28
# Episode 349: Total Reward = 5
# Episode 350: Total Reward = 19
# Episode 351: Total Reward = -4
# Episode 352: Total Reward = 13
# Episode 353: Total Reward = 17
# Episode 354: Total Reward = 13
# Episode 355: Total Reward = 9
# Episode 356: Total Reward = 1
# Episode 357: Total Reward = 21
# Episode 358: Total Reward = 32
# Episode 359: Total Reward = -7
# Episode 360: Total Reward = 26
# Episode 361: Total Reward = 29
# Episode 362: Total Reward = 18
# Episode 363: Total Reward = 0
# Episode 364: Total Reward = 14
# Episode 365: Total Reward = 29
# Episode 366: Total Reward = 19
# Episode 367: Total Reward = -3
# Episode 368: Total Reward = 10
# Episode 369: Total Reward = 17
# Episode 370: Total Reward = 25
# Episode 371: Total Reward = 10
# Episode 372: Total Reward = 20
# Episode 373: Total Reward = 16
# Episode 374: Total Reward = 10
# Episode 375: Total Reward = 20
# Episode 376: Total Reward = 7
# Episode 377: Total Reward = 9
# Episode 378: Total Reward = -8
# Episode 379: Total Reward = 21
# Episode 380: Total Reward = 22
# Episode 381: Total Reward = 1
# Episode 382: Total Reward = 24
# Episode 383: Total Reward = -3
# Episode 384: Total Reward = 21
# Episode 385: Total Reward = 14
# Episode 386: Total Reward = 16
# Episode 387: Total Reward = 14
# Episode 388: Total Reward = 14
# Episode 389: Total Reward = 25
# Episode 390: Total Reward = 10
# Episode 391: Total Reward = 30
# Episode 392: Total Reward = 21
# Episode 393: Total Reward = 14
# Episode 394: Total Reward = 6
# Episode 395: Total Reward = 25
# Episode 396: Total Reward = -4
# Episode 397: Total Reward = 23
# Episode 398: Total Reward = 4
# Episode 399: Total Reward = 14
# Episode 400: Total Reward = 7
# Episode 401: Total Reward = 19
# Episode 402: Total Reward = 24
# Episode 403: Total Reward = 13
# Episode 404: Total Reward = 34
# Episode 405: Total Reward = 8
# Episode 406: Total Reward = 29
# Episode 407: Total Reward = 12
# Episode 408: Total Reward = 28
# Episode 409: Total Reward = 14
# Episode 410: Total Reward = 12
# Episode 411: Total Reward = 26
# Episode 412: Total Reward = 15
# Episode 413: Total Reward = 21
# Episode 414: Total Reward = 5
# Episode 415: Total Reward = 1
# Episode 416: Total Reward = 17
# Episode 417: Total Reward = 18
# Episode 418: Total Reward = 27
# Episode 419: Total Reward = 21
# Episode 420: Total Reward = 22
# Episode 421: Total Reward = 15
# Episode 422: Total Reward = 21
# Episode 423: Total Reward = 30
# Episode 424: Total Reward = 7
# Episode 425: Total Reward = 12
# Episode 426: Total Reward = 15
# Episode 427: Total Reward = 28
# Episode 428: Total Reward = 13
# Episode 429: Total Reward = 14
# Episode 430: Total Reward = 19
# Episode 431: Total Reward = 12
# Episode 432: Total Reward = 19
# Episode 433: Total Reward = 19
# Episode 434: Total Reward = 14
# Episode 435: Total Reward = -8
# Episode 436: Total Reward = 4
# Episode 437: Total Reward = 19
# Episode 438: Total Reward = 20
# Episode 439: Total Reward = 21
# Episode 440: Total Reward = 22
# Episode 441: Total Reward = 19
# Episode 442: Total Reward = 2
# Episode 443: Total Reward = 5
# Episode 444: Total Reward = 12
# Episode 445: Total Reward = 20
# Episode 446: Total Reward = 17
# Episode 447: Total Reward = 9
# Episode 448: Total Reward = 22
# Episode 449: Total Reward = 10
# Episode 450: Total Reward = 21
# Episode 451: Total Reward = 21
# Episode 452: Total Reward = 34
# Episode 453: Total Reward = 14
# Episode 454: Total Reward = 18
# Episode 455: Total Reward = 16
# Episode 456: Total Reward = 14
# Episode 457: Total Reward = 9
# Episode 458: Total Reward = 17
# Episode 459: Total Reward = 6
# Episode 460: Total Reward = 18
# Episode 461: Total Reward = 17
# Episode 462: Total Reward = 16
# Episode 463: Total Reward = 2
# Episode 464: Total Reward = 12
# Episode 465: Total Reward = 8
# Episode 466: Total Reward = 23
# Episode 467: Total Reward = 15
# Episode 468: Total Reward = 9
# Episode 469: Total Reward = 17
# Episode 470: Total Reward = 21
# Episode 471: Total Reward = 2
# Episode 472: Total Reward = 18
# Episode 473: Total Reward = 19
# Episode 474: Total Reward = -3
# Episode 475: Total Reward = 19
# Episode 476: Total Reward = 10
# Episode 477: Total Reward = 18
# Episode 478: Total Reward = 31
# Episode 479: Total Reward = 5
# Episode 480: Total Reward = 0
# Episode 481: Total Reward = 18
# Episode 482: Total Reward = 17
# Episode 483: Total Reward = 10
# Episode 484: Total Reward = 8
# Episode 485: Total Reward = 5
# Episode 486: Total Reward = 15
# Episode 487: Total Reward = 17
# Episode 488: Total Reward = 10
# Episode 489: Total Reward = 17
# Episode 490: Total Reward = 18
# Episode 491: Total Reward = 6
# Episode 492: Total Reward = 5
# Episode 493: Total Reward = 13
# Episode 494: Total Reward = 11
# Episode 495: Total Reward = 17
# Episode 496: Total Reward = -8
# Episode 497: Total Reward = 17
# Episode 498: Total Reward = 8
# Episode 499: Total Reward = 15
# Episode 500: Total Reward = 21
# Episode 501: Total Reward = 21
# Episode 502: Total Reward = 12
# Episode 503: Total Reward = 12
# Episode 504: Total Reward = 23
# Episode 505: Total Reward = 27
# Episode 506: Total Reward = 17
# Episode 507: Total Reward = 19
# Episode 508: Total Reward = 31
# Episode 509: Total Reward = 26
# Episode 510: Total Reward = 15
# Episode 511: Total Reward = -3
# Episode 512: Total Reward = 16
# Episode 513: Total Reward = 21
# Episode 514: Total Reward = 13
# Episode 515: Total Reward = 18
# Episode 516: Total Reward = 34
# Episode 517: Total Reward = 22
# Episode 518: Total Reward = 17
# Episode 519: Total Reward = 16
# Episode 520: Total Reward = 9
# Episode 521: Total Reward = 22
# Episode 522: Total Reward = 19
# Episode 523: Total Reward = 25
# Episode 524: Total Reward = 24
# Episode 525: Total Reward = 20
# Episode 526: Total Reward = 18
# Episode 527: Total Reward = 14
# Episode 528: Total Reward = 15
# Episode 529: Total Reward = 6
# Episode 530: Total Reward = 23
# Episode 531: Total Reward = 14
# Episode 532: Total Reward = 14
# Episode 533: Total Reward = 29
# Episode 534: Total Reward = 6
# Episode 535: Total Reward = 30
# Episode 536: Total Reward = 1
# Episode 537: Total Reward = 2
# Episode 538: Total Reward = 6
# Episode 539: Total Reward = 10
# Episode 540: Total Reward = 20
# Episode 541: Total Reward = 30
# Episode 542: Total Reward = 20
# Episode 543: Total Reward = -3
# Episode 544: Total Reward = 27
# Episode 545: Total Reward = 15
# Episode 546: Total Reward = 20
# Episode 547: Total Reward = 17
# Episode 548: Total Reward = 11
# Episode 549: Total Reward = 13
# Episode 550: Total Reward = 5
# Episode 551: Total Reward = 16
# Episode 552: Total Reward = 21
# Episode 553: Total Reward = 21
# Episode 554: Total Reward = 16
# Episode 555: Total Reward = 23
# Episode 556: Total Reward = 18
# Episode 557: Total Reward = 21
# Episode 558: Total Reward = 3
# Episode 559: Total Reward = -3
# Episode 560: Total Reward = 20
# Episode 561: Total Reward = 18
# Episode 562: Total Reward = 26
# Episode 563: Total Reward = 11
# Episode 564: Total Reward = 18
# Episode 565: Total Reward = 22
# Episode 566: Total Reward = 35
# Episode 567: Total Reward = 20
# Episode 568: Total Reward = 12
# Episode 569: Total Reward = 17
# Episode 570: Total Reward = 11
# Episode 571: Total Reward = 11
# Episode 572: Total Reward = 17
# Episode 573: Total Reward = 13
# Episode 574: Total Reward = 0
# Episode 575: Total Reward = 22
# Episode 576: Total Reward = 0
# Episode 577: Total Reward = 21
# Episode 578: Total Reward = 22
# Episode 579: Total Reward = 24
# Episode 580: Total Reward = 13
# Episode 581: Total Reward = 20
# Episode 582: Total Reward = 31
# Episode 583: Total Reward = 11
# Episode 584: Total Reward = 6
# Episode 585: Total Reward = 9
# Episode 586: Total Reward = 22
# Episode 587: Total Reward = 12
# Episode 588: Total Reward = 17
# Episode 589: Total Reward = 12
# Episode 590: Total Reward = 18
# Episode 591: Total Reward = 16
# Episode 592: Total Reward = 8
# Episode 593: Total Reward = 19
# Episode 594: Total Reward = 14
# Episode 595: Total Reward = 2
# Episode 596: Total Reward = 25
# Episode 597: Total Reward = 8
# Episode 598: Total Reward = 16
# Episode 599: Total Reward = 18
# Episode 600: Total Reward = 26
# Episode 601: Total Reward = 17
# Episode 602: Total Reward = 21
# Episode 603: Total Reward = 13
# Episode 604: Total Reward = 21
# Episode 605: Total Reward = 18
# Episode 606: Total Reward = 26
# Episode 607: Total Reward = -1
# Episode 608: Total Reward = 19
# Episode 609: Total Reward = 7
# Episode 610: Total Reward = 19
# Episode 611: Total Reward = 5
# Episode 612: Total Reward = 7
# Episode 613: Total Reward = 22
# Episode 614: Total Reward = 26
# Episode 615: Total Reward = -4
# Episode 616: Total Reward = 9
# Episode 617: Total Reward = 19
# Episode 618: Total Reward = 9
# Episode 619: Total Reward = 18
# Episode 620: Total Reward = 10
# Episode 621: Total Reward = 24
# Episode 622: Total Reward = 7
# Episode 623: Total Reward = 10
# Episode 624: Total Reward = 2
# Episode 625: Total Reward = 13
# Episode 626: Total Reward = 14
# Episode 627: Total Reward = 13
# Episode 628: Total Reward = 4
# Episode 629: Total Reward = 20
# Episode 630: Total Reward = 25
# Episode 631: Total Reward = -2
# Episode 632: Total Reward = 3
# Episode 633: Total Reward = 12
# Episode 634: Total Reward = 10
# Episode 635: Total Reward = 25
# Episode 636: Total Reward = 17
# Episode 637: Total Reward = 4
# Episode 638: Total Reward = 7
# Episode 639: Total Reward = 20
# Episode 640: Total Reward = 5
# Episode 641: Total Reward = 10
# Episode 642: Total Reward = -12
# Episode 643: Total Reward = 16
# Episode 644: Total Reward = 14
# Episode 645: Total Reward = 28
# Episode 646: Total Reward = -9
# Episode 647: Total Reward = 13
# Episode 648: Total Reward = 20
# Episode 649: Total Reward = 23
# Episode 650: Total Reward = 11
# Episode 651: Total Reward = 12
# Episode 652: Total Reward = 9
# Episode 653: Total Reward = 17
# Episode 654: Total Reward = -10
# Episode 655: Total Reward = 0
# Episode 656: Total Reward = 5
# Episode 657: Total Reward = 8
# Episode 658: Total Reward = 16
# Episode 659: Total Reward = 10
# Episode 660: Total Reward = -1
# Episode 661: Total Reward = 15
# Episode 662: Total Reward = 6
# Episode 663: Total Reward = 13
# Episode 664: Total Reward = 14
# Episode 665: Total Reward = 32
# Episode 666: Total Reward = 18
# Episode 667: Total Reward = 14
# Episode 668: Total Reward = 20
# Episode 669: Total Reward = 13
# Episode 670: Total Reward = 7
# Episode 671: Total Reward = 22
# Episode 672: Total Reward = 10
# Episode 673: Total Reward = 18
# Episode 674: Total Reward = 17
# Episode 675: Total Reward = 9
# Episode 676: Total Reward = 12
# Episode 677: Total Reward = 13
# Episode 678: Total Reward = -7
# Episode 679: Total Reward = 27
# Episode 680: Total Reward = -1
# Episode 681: Total Reward = 15
# Episode 682: Total Reward = 27
# Episode 683: Total Reward = 12
# Episode 684: Total Reward = 17
# Episode 685: Total Reward = 20
# Episode 686: Total Reward = 14
# Episode 687: Total Reward = 14
# Episode 688: Total Reward = 10
# Episode 689: Total Reward = 17
# Episode 690: Total Reward = 20
# Episode 691: Total Reward = 3
# Episode 692: Total Reward = 27
# Episode 693: Total Reward = 24
# Episode 694: Total Reward = 25
# Episode 695: Total Reward = 10
# Episode 696: Total Reward = 19
# Episode 697: Total Reward = 1
# Episode 698: Total Reward = 22
# Episode 699: Total Reward = 29
# Episode 700: Total Reward = 15
# Episode 701: Total Reward = 16
# Episode 702: Total Reward = 23
# Episode 703: Total Reward = 14
# Episode 704: Total Reward = 16
# Episode 705: Total Reward = 19
# Episode 706: Total Reward = 29
# Episode 707: Total Reward = 20
# Episode 708: Total Reward = 23
# Episode 709: Total Reward = 20
# Episode 710: Total Reward = 15
# Episode 711: Total Reward = 13
# Episode 712: Total Reward = 16
# Episode 713: Total Reward = 15
# Episode 714: Total Reward = 20
# Episode 715: Total Reward = 38
# Episode 716: Total Reward = 32
# Episode 717: Total Reward = 29
# Episode 718: Total Reward = 14
# Episode 719: Total Reward = -5
# Episode 720: Total Reward = 21
# Episode 721: Total Reward = 21
# Episode 722: Total Reward = 14
# Episode 723: Total Reward = 23
# Episode 724: Total Reward = 19
# Episode 725: Total Reward = 11
# Episode 726: Total Reward = 2
# Episode 727: Total Reward = 27
# Episode 728: Total Reward = 14
# Episode 729: Total Reward = 26
# Episode 730: Total Reward = 15
# Episode 731: Total Reward = 15
# Episode 732: Total Reward = 9
# Episode 733: Total Reward = 17
# Episode 734: Total Reward = 13
# Episode 735: Total Reward = 21
# Episode 736: Total Reward = 24
# Episode 737: Total Reward = 9
# Episode 738: Total Reward = 32
# Episode 739: Total Reward = 38
# Episode 740: Total Reward = 13
# Episode 741: Total Reward = 15
# Episode 742: Total Reward = 23
# Episode 743: Total Reward = 12
# Episode 744: Total Reward = 13
# Episode 745: Total Reward = 13
# Episode 746: Total Reward = 26
# Episode 747: Total Reward = 11
# Episode 748: Total Reward = 32
# Episode 749: Total Reward = 19
# Episode 750: Total Reward = 5
# Episode 751: Total Reward = 26
# Episode 752: Total Reward = 23
# Episode 753: Total Reward = 3
# Episode 754: Total Reward = 22
# Episode 755: Total Reward = 15
# Episode 756: Total Reward = 17
# Episode 757: Total Reward = 9
# Episode 758: Total Reward = 33
# Episode 759: Total Reward = 27
# Episode 760: Total Reward = 10
# Episode 761: Total Reward = 11
# Episode 762: Total Reward = 15
# Episode 763: Total Reward = 16
# Episode 764: Total Reward = 19
# Episode 765: Total Reward = 2
# Episode 766: Total Reward = 7
# Episode 767: Total Reward = 5
# Episode 768: Total Reward = 27
# Episode 769: Total Reward = 19
# Episode 770: Total Reward = 11
# Episode 771: Total Reward = 6
# Episode 772: Total Reward = 21
# Episode 773: Total Reward = 8
# Episode 774: Total Reward = 11
# Episode 775: Total Reward = 17
# Episode 776: Total Reward = 21
# Episode 777: Total Reward = 8
# Episode 778: Total Reward = 22
# Episode 779: Total Reward = 13
# Episode 780: Total Reward = 24
# Episode 781: Total Reward = 17
# Episode 782: Total Reward = 6
# Episode 783: Total Reward = 9
# Episode 784: Total Reward = 15
# Episode 785: Total Reward = 9
# Episode 786: Total Reward = 19
# Episode 787: Total Reward = 6
# Episode 788: Total Reward = 5
# Episode 789: Total Reward = 4
# Episode 790: Total Reward = 19
# Episode 791: Total Reward = 19
# Episode 792: Total Reward = 11
# Episode 793: Total Reward = 16
# Episode 794: Total Reward = 37
# Episode 795: Total Reward = 15
# Episode 796: Total Reward = 19
# Episode 797: Total Reward = 14
# Episode 798: Total Reward = 6
# Episode 799: Total Reward = 1
# Episode 800: Total Reward = 9
# Episode 801: Total Reward = 12
# Episode 802: Total Reward = 33
# Episode 803: Total Reward = 31
# Episode 804: Total Reward = 10
# Episode 805: Total Reward = 26
# Episode 806: Total Reward = 24
# Episode 807: Total Reward = 5
# Episode 808: Total Reward = 26
# Episode 809: Total Reward = 15
# Episode 810: Total Reward = 14
# Episode 811: Total Reward = 19
# Episode 812: Total Reward = -3
# Episode 813: Total Reward = 14
# Episode 814: Total Reward = 14
# Episode 815: Total Reward = 3
# Episode 816: Total Reward = 17
# Episode 817: Total Reward = 12
# Episode 818: Total Reward = 18
# Episode 819: Total Reward = 19
# Episode 820: Total Reward = 15
# Episode 821: Total Reward = 19
# Episode 822: Total Reward = -10
# Episode 823: Total Reward = 14
# Episode 824: Total Reward = 19
# Episode 825: Total Reward = 28
# Episode 826: Total Reward = 7
# Episode 827: Total Reward = 2
# Episode 828: Total Reward = 25
# Episode 829: Total Reward = 14
# Episode 830: Total Reward = 22
# Episode 831: Total Reward = 32
# Episode 832: Total Reward = 2
# Episode 833: Total Reward = 4
# Episode 834: Total Reward = 22
# Episode 835: Total Reward = 16
# Episode 836: Total Reward = 4
# Episode 837: Total Reward = 32
# Episode 838: Total Reward = 9
# Episode 839: Total Reward = 35
# Episode 840: Total Reward = 24
# Episode 841: Total Reward = 11
# Episode 842: Total Reward = -7
# Episode 843: Total Reward = 28
# Episode 844: Total Reward = 24
# Episode 845: Total Reward = 35
# Episode 846: Total Reward = 13
# Episode 847: Total Reward = 28
# Episode 848: Total Reward = 8
# Episode 849: Total Reward = 25
# Episode 850: Total Reward = 8
# Episode 851: Total Reward = 37
# Episode 852: Total Reward = -4
# Episode 853: Total Reward = 12
# Episode 854: Total Reward = 9
# Episode 855: Total Reward = 18
# Episode 856: Total Reward = 22
# Episode 857: Total Reward = 20
# Episode 858: Total Reward = 28
# Episode 859: Total Reward = 6
# Episode 860: Total Reward = 22
# Episode 861: Total Reward = 7
# Episode 862: Total Reward = 33
# Episode 863: Total Reward = 18
# Episode 864: Total Reward = 32
# Episode 865: Total Reward = -8
# Episode 866: Total Reward = 24
# Episode 867: Total Reward = 6
# Episode 868: Total Reward = 11
# Episode 869: Total Reward = 12
# Episode 870: Total Reward = 8
# Episode 871: Total Reward = 25
# Episode 872: Total Reward = 23
# Episode 873: Total Reward = 31
# Episode 874: Total Reward = 9
# Episode 875: Total Reward = 19
# Episode 876: Total Reward = 27
# Episode 877: Total Reward = 11
# Episode 878: Total Reward = 0
# Episode 879: Total Reward = 16
# Episode 880: Total Reward = 21
# Episode 881: Total Reward = 20
# Episode 882: Total Reward = 15
# Episode 883: Total Reward = 6
# Episode 884: Total Reward = 5
# Episode 885: Total Reward = 20
# Episode 886: Total Reward = -16
# Episode 887: Total Reward = 1
# Episode 888: Total Reward = 14
# Episode 889: Total Reward = 12
# Episode 890: Total Reward = 24
# Episode 891: Total Reward = 26
# Episode 892: Total Reward = 30
# Episode 893: Total Reward = 14
# Episode 894: Total Reward = 19
# Episode 895: Total Reward = 22
# Episode 896: Total Reward = 19
# Episode 897: Total Reward = 33
# Episode 898: Total Reward = 21
# Episode 899: Total Reward = 17
# Episode 900: Total Reward = 14
# Episode 901: Total Reward = -7
# Episode 902: Total Reward = -3
# Episode 903: Total Reward = 20
# Episode 904: Total Reward = 9
# Episode 905: Total Reward = 39
# Episode 906: Total Reward = 31
# Episode 907: Total Reward = 31
# Episode 908: Total Reward = 35
# Episode 909: Total Reward = 19
# Episode 910: Total Reward = 24
# Episode 911: Total Reward = -6
# Episode 912: Total Reward = 12
# Episode 913: Total Reward = 22
# Episode 914: Total Reward = 32
# Episode 915: Total Reward = 28
# Episode 916: Total Reward = 24
# Episode 917: Total Reward = 20
# Episode 918: Total Reward = 13
# Episode 919: Total Reward = 22
# Episode 920: Total Reward = 19
# Episode 921: Total Reward = 20
# Episode 922: Total Reward = 13
# Episode 923: Total Reward = 14
# Episode 924: Total Reward = -16
# Episode 925: Total Reward = 21
# Episode 926: Total Reward = 3
# Episode 927: Total Reward = 10
# Episode 928: Total Reward = 37
# Episode 929: Total Reward = 20
# Episode 930: Total Reward = 21
# Episode 931: Total Reward = 28
# Episode 932: Total Reward = 17
# Episode 933: Total Reward = 15
# Episode 934: Total Reward = 24
# Episode 935: Total Reward = 17
# Episode 936: Total Reward = 27
# Episode 937: Total Reward = 33
# Episode 938: Total Reward = 17
# Episode 939: Total Reward = 18
# Episode 940: Total Reward = 7
# Episode 941: Total Reward = 20
# Episode 942: Total Reward = 41
# Episode 943: Total Reward = 28
# Episode 944: Total Reward = 0
# Episode 945: Total Reward = 24
# Episode 946: Total Reward = 18
# Episode 947: Total Reward = 13
# Episode 948: Total Reward = 29
# Episode 949: Total Reward = -1
# Episode 950: Total Reward = 14
# Episode 951: Total Reward = 31
# Episode 952: Total Reward = 19
# Episode 953: Total Reward = 16
# Episode 954: Total Reward = 27
# Episode 955: Total Reward = 9
# Episode 956: Total Reward = 17
# Episode 957: Total Reward = -4
# Episode 958: Total Reward = 12
# Episode 959: Total Reward = 17
# Episode 960: Total Reward = 19
# Episode 961: Total Reward = 8
# Episode 962: Total Reward = 7
# Episode 963: Total Reward = 4
# Episode 964: Total Reward = 17
# Episode 965: Total Reward = 1
# Episode 966: Total Reward = -7
# Episode 967: Total Reward = 0
# Episode 968: Total Reward = 7
# Episode 969: Total Reward = 11
# Episode 970: Total Reward = -9
# Episode 971: Total Reward = 8
# Episode 972: Total Reward = 28
# Episode 973: Total Reward = 5
# Episode 974: Total Reward = 17
# Episode 975: Total Reward = 9
# Episode 976: Total Reward = 7
# Episode 977: Total Reward = -2
# Episode 978: Total Reward = 8
# Episode 979: Total Reward = 4
# Episode 980: Total Reward = -8
# Episode 981: Total Reward = 19
# Episode 982: Total Reward = 27
# Episode 983: Total Reward = 17
# Episode 984: Total Reward = 19
# Episode 985: Total Reward = 33
# Episode 986: Total Reward = -3
# Episode 987: Total Reward = 20
# Episode 988: Total Reward = 39
# Episode 989: Total Reward = 19
# Episode 990: Total Reward = 6
# Episode 991: Total Reward = 14
# Episode 992: Total Reward = 27
# Episode 993: Total Reward = 7
# Episode 994: Total Reward = 27
# Episode 995: Total Reward = 4
# Episode 996: Total Reward = -6
# Episode 997: Total Reward = 21
# Episode 998: Total Reward = 5
# Episode 999: Total Reward = 17
